# %% [markdown]
# # Demo 1: Convolutional Neural Network (CNN)
# This demo we will demo code for using Convolutional Neural
# Network to solve the classification problem:
# -   Problem: Surface Defect classification (with the NEU surface defect dataset)
# -   Dataset: NEU surface defect dataset <http://faculty.neu.edu.cn/songkechen/zh_CN/zhym/263269/list/index.htm>(NEU SDD)
# -   Library packages:
#     -   Numpy (Numpy arrays are very fast and can perform large computations in a very short time)
#     -   PIL (Simple image processing package: read, show, resize,...)
#     -   Matplotlib (Plot package: visualize result,....)
#     -   TensorFlow (This is an open-source library that is used for DL/ML/AI)
#     -   Scikit-Learn (Machine Learning models: KNN,SVM,Decision Tree, Metrics,...)
# Tasks Outlines:
# ## 0. Task 0: Preparing dataset
# -   Downloads dataset, unpacking dataset,...
# -   Transform it to input (features) and ouput (labels) where the model in tensorflow library can read, and training on,...
# -   Normalize or standardlize dataset (we may do it after some evaluations on the raw data)
# -   Devide dataset to trainset and testset (maybe one more validation_set)
# ## 1. Task 1: Constructing model by using TensorFlow library:
# -   Create a convolutional neural network for classification problem
# -   Training model on our trainset and applying the early stopping during the training
# ## 2. Task 2: Evaluating the performance of trained model on the testset
# -   Predict the label (which class) for each input image in the testset
# -   Compute the metrics (quantitative measurements)
#     -   For example on Classification task: Accuracy, Precesion, Recall, Confusion Matrix, F1-Score, Cross-Entropy Loss,...
# ## 3. Task 3: Training model with data augmentation, save the best model, loading the trained model.
# -   Training model train data_augmentation
# -   Loading the trained model and evaluating on the test set.
# *****************************************************************************

# %% [markdown]
# ## Import all packages

# %%
import os
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPool2D
from keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# ## 0. Task 0: Preparing Dataset
#
# Go to the notebook file: Demo_Read_NEU_dataset.ipynb to get detail of demo code for this step
#
# ### 0.1. Define a function get all paths to each image in the dataset and the class label of each image

# %%
def get_all_img_label_path(input_dir:str,
                            img_suffix = '.bmp')->(list,list):
    """
    parameters:
    -   input_dir: the directory to the data folder
    -   img_suffix: siffix type of image in the data folder to read
    output: a tuple of two lists:
    -   List of all path to each image in the data folder
    -   List of relative class for each image in the data folder
    """
    label_to_number = {"Cr":0,"In":1,"Pa":2,"PS":3,"RS":4,"Sc":5}
    list_img_paths = []
    list_labels = []
    for root,dirs,files in os.walk(input_dir):
        for file in files:
            file_name,file_suffix = os.path.splitext(file)
            if file_suffix == img_suffix:
                list_img_paths.append(os.path.join(root,file))
                list_labels.append(label_to_number[file_name[:2]])
    return (list_img_paths,list_labels)

# %% [markdown]
# ### 0.2. Define a function to get all image array and its class label (which are in type np.array)
# In this function we also resize the all image to the same new size = (width, height)

# %%
# Resize the image to small dimensional of width and height
def get_data(list_img_paths:list,
             list_labels:list,
             is_resize:bool= True,
             width:int = 8,
             height:int = 8) -> (np.array,np.array):
    """
    Parameters:
    -   list_img_paths: List of all paths to image in the data folder
    -   list_labels: The list of labels relative to each image in the list_img_paths
    -   is_resize: Default is True means resize all image in the dataset
        to the new size (width,height)
    -   width: The width size which we want to resize to
    -   height: The height size which we want to resize to

    Output: A tuple of two arrays
    -   data_array with shape (N,h,w), where
        -   N is the number of image
        -   h is the height
        -   w is the width
    -   label_array with shape (N,)
    """
    data = []
    for i in range(len(list_img_paths)):
        path_img = list_img_paths[i]
        img = Image.open(path_img)
        if is_resize:
            img = img.resize(size = (width,height),
                            resample=Image.BICUBIC)
        data.append(np.array(img))
    return (np.array(data),np.array(list_labels))

# %% [markdown]
# ### 0.3. Getting data by using two previouse function

# %%
# Get the list of all path to images, and the list of relative labels
dir_NEUCLS = "/Users/user/Victor2023/Dataset/NEU-CLS"
list_img_paths,list_labels = get_all_img_label_path(input_dir=dir_NEUCLS,
                                                    img_suffix='.bmp')

width = 32
height = 32
n_channels = 1
X,label = get_data(list_img_paths=list_img_paths,
               list_labels=list_labels,
               is_resize=True,
               width=width,
               height= height)

# %% [markdown]
# ### Note!
# The shape of data image input for CNN model should be (N_samples,height, width, n_channels). In which:
# -   N_samples: The total number of samples we have (number of images)
# -   height: the height of image
# -   width: the width of image
# -   n_channels: number of channels in image (our case is gray scale image => n_channels = 1)
#
# Back to our data:
# -   Data is image in grayscale we resize to same size (height,width), here is 32 x 32 pixels. The number of channels in image is 1
# -   We have to reshape our data from (N_samples,height,width) to (N_samples,height,width,n_channels)

# %%
n_samples = X.shape[0]
X = X.reshape((n_samples,height,width,n_channels))
# Scaling feature from range [0,255] to range [0,1]
# Each pixel is a feature of input image, which has normally value in range [0,255] 
X = X/255

# Convert integers to dummy variables (i.e. one hot encoded)
# Formating the truth label in form of output of model
# y now is the truth output which model must learn to predict
y = to_categorical(label)

# %%
print("The currently shape of input dataset X is:", X.shape)
print("The currently shape of dummy y is:", y.shape)
# Out:
# The currently shape of input dataset X is: (1800, 32, 32, 1)
# The currently shape of dummy y is: (1800, 6)

# %% [markdown]
# ### 0.4. Deviding our dataset to trainset, validset and testset

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,shuffle=False)
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2,shuffle=False)

# %%
print("Number of samples in the train subset:", len(y_train))
print("Number of samples in the train subset:", len(y_val))
print("Number of samples in the test subset:", len(y_test))
# Out:
# Number of samples in the train subset: 1296
# Number of samples in the train subset: 324
# Number of samples in the test subset: 180

# %% [markdown]
# ## 1. Task 1: Constructing model by using TensorFlow library:

# %% [markdown]
# ### 1.1. Creating Convolutional Neural Network model
# CNN with 2 Convolution Layers and 2 Fully Connected Layers.
#
# The model CNN takes an input tensors of shape (height,width,n_channels). Here, we configure the CNN to process inputs of shape (32,32,1). So, we passing the argument input_shape = (32,32,1) to the first layer.
#
# -   The 1st layer is Conv2D layer for the convolution operation. Here we choose feature map kernel size = (5,5)
# -   The 2nd layer is the MaxPooling2D for reduces the dimensionality of each feature. Here we choose the pooling window size = (2,2)
# -   The 3rd layer is Dropout for reduces the overfitting. Here we use 0.2 dropout will randomly disable 20% of the neurons.
# -   The 4th, 5th, 6th layers are just the repeat of 1st,2nd,3rd layers
# -   The next step is for Fully-Connected layers:
#     -   Flattening the 3D outputs of previous layer to 1D by Flatten layer
#     -   Adding Dense layer (Linear mapping)
# -   In the last Dense layer, we use softmax as activation. It enables our to calculate the output based on the probabilities. Each class is assigned a probability. For final predict we apply the argmax to find the class with the maximum probability.

# %%
# define the input_shape
input_shape = (height,width,n_channels)
# Define the model CNN
model_cnn = Sequential()
## Convolution layer1 : Conv2d => MaxPool2D => Dropout
model_cnn.add(Conv2D(32,
                    kernel_size=(5,5),
                    activation='relu',
                    input_shape = input_shape))
model_cnn.add(MaxPool2D(pool_size=(2,2)))
model_cnn.add(Dropout(0.2))
## Convolution layer2 : Conv2d => MaxPool2D => Dropout
model_cnn.add(Conv2D(16,
                    kernel_size=(3,3),
                    activation='relu',
                    input_shape = input_shape))
model_cnn.add(MaxPool2D(pool_size=(2,2)))
model_cnn.add(Dropout(0.2))
## Fully-Connected layers:
model_cnn.add(Flatten())
model_cnn.add(Dense(128,activation='relu'))
model_cnn.add(Dense(6,activation='softmax'))

# %%
# Showo the model summary
model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        832
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 16)        4624
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 16)          0
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_2 (Dense)             (None, 128)               73856
#
#  dense_3 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 80,086
# Trainable params: 80,086
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Model summary:
#
# Layer convolutional 1:
# -   input shape: (32,32,1)
#     -   n_channels: 1
# -   output shape: (28,28,32) =>
#     -   32 filters (32 kernals) each of size 5x5,
#     -   32 biases
# -   The total parameters is: $32*5*5*1 + 32 = 832$
#
# Layer convolutional 2:
# -   input shape: (14,14,32)
#     -   n_channels: 32
# -   output shape: (12,12,16)
#     -   16 filters (16 kernals) each of size 3x3,
#     -   16 biases
# -   The total parameters is: $16*3*3*32 + 16 = 4624$
#
# Layer Dense 1:
# -   input shape: 576
# -   output shape: 128 => bias shape: 128
# -   weight shape: (576,128)
# -   The total parameters is: $576*128+128 = 73856$
#
# Layer Dense 2 (final output layer):
# -   input shape: 128
# -   output shape: 6 => bias shape: 6
# -   weight shape: (128,6)
# -   The total parameters is: $128*6 + 6 = 774$

# %% [markdown]
# ### 1.2. Training model with EarlyStopping, ModelCheckpoint, and ReduceLROnPlateau

# %%
# Define EarlyStopping, ModelCheckpoint, ReduceLearningRateOnPlateau.
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   verbose=1,
                   patience=30)
mc = ModelCheckpoint('best_model_cnn.h5',
                     monitor='val_accuracy',
                     mode='max',
                     verbose=1,
                     save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=30,
                              min_lr=0.0001,
                              mode = 'min')

# %%
# Training model with 500 epochs with earlystopping
epochs = 500
optimizer = keras.optimizers.Adam()
loss = keras.losses.categorical_crossentropy
q_metrics = ['accuracy']
model_cnn.compile(optimizer=optimizer,
                   loss = loss,
                   metrics=q_metrics)
history = model_cnn.fit(X_train,y_train,
                         batch_size=32,
                         epochs = epochs,
                         validation_data=(X_val,y_val),
                         verbose=2,
                         callbacks=[es,mc,reduce_lr])
# Out:
# Epoch 1/500
#
# Epoch 1: val_accuracy improved from -inf to 0.34259, saving model to best_model_cnn.h5
# 41/41 - 3s - loss: 1.7418 - accuracy: 0.2315 - val_loss: 1.6512 - val_accuracy: 0.3426 - lr: 0.0010 - 3s/epoch - 68ms/step
# Epoch 2/500
#
# Epoch 2: val_accuracy improved from 0.34259 to 0.61420, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 1.4121 - accuracy: 0.3912 - val_loss: 1.3117 - val_accuracy: 0.6142 - lr: 0.0010 - 989ms/epoch - 24ms/step
# Epoch 3/500
#
# Epoch 3: val_accuracy did not improve from 0.61420
# 41/41 - 1s - loss: 1.1440 - accuracy: 0.5633 - val_loss: 1.1000 - val_accuracy: 0.6019 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 4/500
#
# Epoch 4: val_accuracy did not improve from 0.61420
# 41/41 - 1s - loss: 0.9763 - accuracy: 0.6335 - val_loss: 1.1162 - val_accuracy: 0.5617 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 5/500
#
# Epoch 5: val_accuracy did not improve from 0.61420
# 41/41 - 2s - loss: 0.9008 - accuracy: 0.6752 - val_loss: 1.0050 - val_accuracy: 0.6080 - lr: 0.0010 - 2s/epoch - 45ms/step
# Epoch 6/500
#
# Epoch 6: val_accuracy did not improve from 0.61420
# 41/41 - 1s - loss: 0.7986 - accuracy: 0.7338 - val_loss: 1.3552 - val_accuracy: 0.4537 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 7/500
#
# Epoch 7: val_accuracy did not improve from 0.61420
# 41/41 - 1s - loss: 0.7616 - accuracy: 0.7492 - val_loss: 0.9667 - val_accuracy: 0.5833 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 8/500
#
# Epoch 8: val_accuracy improved from 0.61420 to 0.76543, saving model to best_model_cnn.h5
# 41/41 - 2s - loss: 0.6877 - accuracy: 0.7785 - val_loss: 0.7360 - val_accuracy: 0.7654 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 9/500
#
# Epoch 9: val_accuracy did not improve from 0.76543
# 41/41 - 1s - loss: 0.6268 - accuracy: 0.8002 - val_loss: 0.7270 - val_accuracy: 0.7284 - lr: 0.0010 - 1s/epoch - 27ms/step
# Epoch 10/500
#
# Epoch 10: val_accuracy improved from 0.76543 to 0.81481, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.6349 - accuracy: 0.7870 - val_loss: 0.6737 - val_accuracy: 0.8148 - lr: 0.0010 - 1s/epoch - 35ms/step
# Epoch 11/500
#
# Epoch 11: val_accuracy did not improve from 0.81481
# 41/41 - 1s - loss: 0.5723 - accuracy: 0.8048 - val_loss: 0.6418 - val_accuracy: 0.7840 - lr: 0.0010 - 930ms/epoch - 23ms/step
# Epoch 12/500
#
# Epoch 12: val_accuracy did not improve from 0.81481
# 41/41 - 1s - loss: 0.5039 - accuracy: 0.8333 - val_loss: 0.7805 - val_accuracy: 0.6975 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 13/500
#
# Epoch 13: val_accuracy improved from 0.81481 to 0.83951, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.5057 - accuracy: 0.8279 - val_loss: 0.5191 - val_accuracy: 0.8395 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 14/500
#
# Epoch 14: val_accuracy did not improve from 0.83951
# 41/41 - 1s - loss: 0.4580 - accuracy: 0.8441 - val_loss: 0.6075 - val_accuracy: 0.7469 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 15/500
#
# Epoch 15: val_accuracy improved from 0.83951 to 0.85802, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.3776 - accuracy: 0.8696 - val_loss: 0.4685 - val_accuracy: 0.8580 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 16/500
#
# Epoch 16: val_accuracy improved from 0.85802 to 0.86420, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.3814 - accuracy: 0.8719 - val_loss: 0.4233 - val_accuracy: 0.8642 - lr: 0.0010 - 1s/epoch - 29ms/step
# Epoch 17/500
#
# Epoch 17: val_accuracy did not improve from 0.86420
# 41/41 - 1s - loss: 0.3889 - accuracy: 0.8634 - val_loss: 0.4600 - val_accuracy: 0.8241 - lr: 0.0010 - 1s/epoch - 25ms/step
# Epoch 18/500
#
# Epoch 18: val_accuracy did not improve from 0.86420
# 41/41 - 2s - loss: 0.3458 - accuracy: 0.8789 - val_loss: 0.4365 - val_accuracy: 0.8457 - lr: 0.0010 - 2s/epoch - 43ms/step
# Epoch 19/500
#
# Epoch 19: val_accuracy did not improve from 0.86420
# 41/41 - 1s - loss: 0.4230 - accuracy: 0.8495 - val_loss: 0.6133 - val_accuracy: 0.7593 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 20/500
#
# Epoch 20: val_accuracy did not improve from 0.86420
# 41/41 - 1s - loss: 0.3419 - accuracy: 0.8827 - val_loss: 0.4440 - val_accuracy: 0.8488 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 21/500
#
# Epoch 21: val_accuracy did not improve from 0.86420
# 41/41 - 1s - loss: 0.2828 - accuracy: 0.9020 - val_loss: 0.4203 - val_accuracy: 0.8364 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 22/500
#
# Epoch 22: val_accuracy improved from 0.86420 to 0.87654, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.2844 - accuracy: 0.8966 - val_loss: 0.3788 - val_accuracy: 0.8765 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 23/500
#
# Epoch 23: val_accuracy did not improve from 0.87654
# 41/41 - 1s - loss: 0.2897 - accuracy: 0.8981 - val_loss: 0.4293 - val_accuracy: 0.8457 - lr: 0.0010 - 1s/epoch - 25ms/step
# Epoch 24/500
#
# Epoch 24: val_accuracy did not improve from 0.87654
# 41/41 - 2s - loss: 0.3099 - accuracy: 0.8843 - val_loss: 0.4639 - val_accuracy: 0.8333 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 25/500
#
# Epoch 25: val_accuracy did not improve from 0.87654
# 41/41 - 2s - loss: 0.2969 - accuracy: 0.8966 - val_loss: 0.5005 - val_accuracy: 0.8210 - lr: 0.0010 - 2s/epoch - 56ms/step
# Epoch 26/500
#
# Epoch 26: val_accuracy did not improve from 0.87654
# 41/41 - 2s - loss: 0.2736 - accuracy: 0.9035 - val_loss: 0.4608 - val_accuracy: 0.8148 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 27/500
#
# Epoch 27: val_accuracy did not improve from 0.87654
# 41/41 - 1s - loss: 0.3368 - accuracy: 0.8843 - val_loss: 0.3895 - val_accuracy: 0.8611 - lr: 0.0010 - 1s/epoch - 29ms/step
# Epoch 28/500
#
# Epoch 28: val_accuracy did not improve from 0.87654
# 41/41 - 2s - loss: 0.2451 - accuracy: 0.9228 - val_loss: 0.3443 - val_accuracy: 0.8765 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 29/500
#
# Epoch 29: val_accuracy improved from 0.87654 to 0.88889, saving model to best_model_cnn.h5
# 41/41 - 2s - loss: 0.2344 - accuracy: 0.9151 - val_loss: 0.3184 - val_accuracy: 0.8889 - lr: 0.0010 - 2s/epoch - 48ms/step
# Epoch 30/500
#
# Epoch 30: val_accuracy did not improve from 0.88889
# 41/41 - 2s - loss: 0.2760 - accuracy: 0.9051 - val_loss: 0.5229 - val_accuracy: 0.7901 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 31/500
#
# Epoch 31: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.4717 - accuracy: 0.8225 - val_loss: 0.5219 - val_accuracy: 0.8056 - lr: 0.0010 - 1s/epoch - 25ms/step
# Epoch 32/500
#
# Epoch 32: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.3113 - accuracy: 0.8927 - val_loss: 0.3932 - val_accuracy: 0.8642 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 33/500
#
# Epoch 33: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.3373 - accuracy: 0.8835 - val_loss: 0.3599 - val_accuracy: 0.8796 - lr: 0.0010 - 1s/epoch - 27ms/step
# Epoch 34/500
#
# Epoch 34: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.2741 - accuracy: 0.9028 - val_loss: 0.3377 - val_accuracy: 0.8796 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 35/500
#
# Epoch 35: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.2241 - accuracy: 0.9298 - val_loss: 0.4214 - val_accuracy: 0.8519 - lr: 0.0010 - 1s/epoch - 26ms/step
# Epoch 36/500
#
# Epoch 36: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.1948 - accuracy: 0.9390 - val_loss: 0.3682 - val_accuracy: 0.8704 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 37/500
#
# Epoch 37: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.2897 - accuracy: 0.8966 - val_loss: 0.3594 - val_accuracy: 0.8765 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 38/500
#
# Epoch 38: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.2233 - accuracy: 0.9290 - val_loss: 0.4183 - val_accuracy: 0.8364 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 39/500
#
# Epoch 39: val_accuracy did not improve from 0.88889
# 41/41 - 1s - loss: 0.2364 - accuracy: 0.9221 - val_loss: 0.4361 - val_accuracy: 0.8210 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 40/500
#
# Epoch 40: val_accuracy did not improve from 0.88889
# 41/41 - 2s - loss: 0.2559 - accuracy: 0.9059 - val_loss: 0.3121 - val_accuracy: 0.8889 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 41/500
#
# Epoch 41: val_accuracy did not improve from 0.88889
# 41/41 - 2s - loss: 0.1764 - accuracy: 0.9437 - val_loss: 0.3706 - val_accuracy: 0.8611 - lr: 0.0010 - 2s/epoch - 45ms/step
# Epoch 42/500
#
# Epoch 42: val_accuracy improved from 0.88889 to 0.89198, saving model to best_model_cnn.h5
# 41/41 - 2s - loss: 0.2058 - accuracy: 0.9290 - val_loss: 0.3102 - val_accuracy: 0.8920 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 43/500
#
# Epoch 43: val_accuracy did not improve from 0.89198
# 41/41 - 2s - loss: 0.2225 - accuracy: 0.9236 - val_loss: 0.7969 - val_accuracy: 0.7191 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 44/500
#
# Epoch 44: val_accuracy did not improve from 0.89198
# 41/41 - 2s - loss: 0.3171 - accuracy: 0.8889 - val_loss: 0.3443 - val_accuracy: 0.8796 - lr: 0.0010 - 2s/epoch - 47ms/step
# Epoch 45/500
#
# Epoch 45: val_accuracy improved from 0.89198 to 0.89815, saving model to best_model_cnn.h5
# 41/41 - 2s - loss: 0.1913 - accuracy: 0.9383 - val_loss: 0.3070 - val_accuracy: 0.8981 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 46/500
#
# Epoch 46: val_accuracy improved from 0.89815 to 0.90123, saving model to best_model_cnn.h5
# 41/41 - 2s - loss: 0.2089 - accuracy: 0.9306 - val_loss: 0.3069 - val_accuracy: 0.9012 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 47/500
#
# Epoch 47: val_accuracy did not improve from 0.90123
# 41/41 - 2s - loss: 0.2214 - accuracy: 0.9282 - val_loss: 0.3195 - val_accuracy: 0.8858 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 48/500
#
# Epoch 48: val_accuracy did not improve from 0.90123
# 41/41 - 2s - loss: 0.1859 - accuracy: 0.9360 - val_loss: 0.3777 - val_accuracy: 0.8642 - lr: 0.0010 - 2s/epoch - 44ms/step
# Epoch 49/500
#
# Epoch 49: val_accuracy did not improve from 0.90123
# 41/41 - 2s - loss: 0.2672 - accuracy: 0.8989 - val_loss: 0.3514 - val_accuracy: 0.8735 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 50/500
#
# Epoch 50: val_accuracy did not improve from 0.90123
# 41/41 - 1s - loss: 0.1780 - accuracy: 0.9406 - val_loss: 0.3415 - val_accuracy: 0.8796 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 51/500
#
# Epoch 51: val_accuracy did not improve from 0.90123
# 41/41 - 1s - loss: 0.1833 - accuracy: 0.9375 - val_loss: 0.3527 - val_accuracy: 0.8858 - lr: 0.0010 - 859ms/epoch - 21ms/step
# Epoch 52/500
#
# Epoch 52: val_accuracy did not improve from 0.90123
# 41/41 - 1s - loss: 0.1700 - accuracy: 0.9452 - val_loss: 0.3271 - val_accuracy: 0.8796 - lr: 0.0010 - 856ms/epoch - 21ms/step
# Epoch 53/500
#
# Epoch 53: val_accuracy did not improve from 0.90123
# 41/41 - 1s - loss: 0.1717 - accuracy: 0.9406 - val_loss: 0.2798 - val_accuracy: 0.8981 - lr: 0.0010 - 859ms/epoch - 21ms/step
# Epoch 54/500
#
# Epoch 54: val_accuracy improved from 0.90123 to 0.91049, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.1866 - accuracy: 0.9406 - val_loss: 0.2555 - val_accuracy: 0.9105 - lr: 0.0010 - 1s/epoch - 29ms/step
# Epoch 55/500
#
# Epoch 55: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1438 - accuracy: 0.9583 - val_loss: 0.2660 - val_accuracy: 0.8889 - lr: 0.0010 - 1s/epoch - 27ms/step
# Epoch 56/500
#
# Epoch 56: val_accuracy did not improve from 0.91049
# 41/41 - 2s - loss: 0.1296 - accuracy: 0.9552 - val_loss: 0.2931 - val_accuracy: 0.8951 - lr: 0.0010 - 2s/epoch - 45ms/step
# Epoch 57/500
#
# Epoch 57: val_accuracy did not improve from 0.91049
# 41/41 - 2s - loss: 0.1311 - accuracy: 0.9545 - val_loss: 0.2746 - val_accuracy: 0.8920 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 58/500
#
# Epoch 58: val_accuracy did not improve from 0.91049
# 41/41 - 2s - loss: 0.1648 - accuracy: 0.9444 - val_loss: 0.3204 - val_accuracy: 0.8796 - lr: 0.0010 - 2s/epoch - 46ms/step
# Epoch 59/500
#
# Epoch 59: val_accuracy did not improve from 0.91049
# 41/41 - 2s - loss: 0.1967 - accuracy: 0.9306 - val_loss: 0.3143 - val_accuracy: 0.8951 - lr: 0.0010 - 2s/epoch - 42ms/step
# Epoch 60/500
#
# Epoch 60: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1304 - accuracy: 0.9599 - val_loss: 0.3312 - val_accuracy: 0.9074 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 61/500
#
# Epoch 61: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1584 - accuracy: 0.9483 - val_loss: 0.3382 - val_accuracy: 0.8827 - lr: 0.0010 - 1s/epoch - 26ms/step
# Epoch 62/500
#
# Epoch 62: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1341 - accuracy: 0.9552 - val_loss: 0.2834 - val_accuracy: 0.8920 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 63/500
#
# Epoch 63: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1905 - accuracy: 0.9336 - val_loss: 0.4260 - val_accuracy: 0.8426 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 64/500
#
# Epoch 64: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1506 - accuracy: 0.9468 - val_loss: 0.2988 - val_accuracy: 0.8858 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 65/500
#
# Epoch 65: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1872 - accuracy: 0.9360 - val_loss: 0.3303 - val_accuracy: 0.8889 - lr: 0.0010 - 917ms/epoch - 22ms/step
# Epoch 66/500
#
# Epoch 66: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1676 - accuracy: 0.9460 - val_loss: 0.3121 - val_accuracy: 0.9074 - lr: 0.0010 - 882ms/epoch - 22ms/step
# Epoch 67/500
#
# Epoch 67: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1466 - accuracy: 0.9514 - val_loss: 0.2625 - val_accuracy: 0.9043 - lr: 0.0010 - 897ms/epoch - 22ms/step
# Epoch 68/500
#
# Epoch 68: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1636 - accuracy: 0.9452 - val_loss: 0.3234 - val_accuracy: 0.8735 - lr: 0.0010 - 882ms/epoch - 22ms/step
# Epoch 69/500
#
# Epoch 69: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1234 - accuracy: 0.9552 - val_loss: 0.2690 - val_accuracy: 0.8889 - lr: 0.0010 - 875ms/epoch - 21ms/step
# Epoch 70/500
#
# Epoch 70: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1276 - accuracy: 0.9568 - val_loss: 0.2811 - val_accuracy: 0.9074 - lr: 0.0010 - 952ms/epoch - 23ms/step
# Epoch 71/500
#
# Epoch 71: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1231 - accuracy: 0.9576 - val_loss: 0.2898 - val_accuracy: 0.9012 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 72/500
#
# Epoch 72: val_accuracy did not improve from 0.91049
# 41/41 - 1s - loss: 0.1771 - accuracy: 0.9367 - val_loss: 0.2687 - val_accuracy: 0.8981 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 73/500
#
# Epoch 73: val_accuracy improved from 0.91049 to 0.91667, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.1387 - accuracy: 0.9522 - val_loss: 0.2815 - val_accuracy: 0.9167 - lr: 0.0010 - 937ms/epoch - 23ms/step
# Epoch 74/500
#
# Epoch 74: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1163 - accuracy: 0.9622 - val_loss: 0.3027 - val_accuracy: 0.9043 - lr: 0.0010 - 965ms/epoch - 24ms/step
# Epoch 75/500
#
# Epoch 75: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1165 - accuracy: 0.9583 - val_loss: 0.2846 - val_accuracy: 0.8981 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 76/500
#
# Epoch 76: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1218 - accuracy: 0.9591 - val_loss: 0.3179 - val_accuracy: 0.8889 - lr: 0.0010 - 1s/epoch - 27ms/step
# Epoch 77/500
#
# Epoch 77: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1543 - accuracy: 0.9383 - val_loss: 0.2923 - val_accuracy: 0.8858 - lr: 0.0010 - 941ms/epoch - 23ms/step
# Epoch 78/500
#
# Epoch 78: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1549 - accuracy: 0.9475 - val_loss: 0.4222 - val_accuracy: 0.8673 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 79/500
#
# Epoch 79: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1135 - accuracy: 0.9668 - val_loss: 0.3063 - val_accuracy: 0.8951 - lr: 0.0010 - 1s/epoch - 29ms/step
# Epoch 80/500
#
# Epoch 80: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1282 - accuracy: 0.9522 - val_loss: 0.2716 - val_accuracy: 0.9012 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 81/500
#
# Epoch 81: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1030 - accuracy: 0.9668 - val_loss: 0.4550 - val_accuracy: 0.8642 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 82/500
#
# Epoch 82: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1078 - accuracy: 0.9591 - val_loss: 0.2961 - val_accuracy: 0.8951 - lr: 0.0010 - 1s/epoch - 27ms/step
# Epoch 83/500
#
# Epoch 83: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.0932 - accuracy: 0.9645 - val_loss: 0.2386 - val_accuracy: 0.9105 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 84/500
#
# Epoch 84: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1262 - accuracy: 0.9576 - val_loss: 0.2277 - val_accuracy: 0.9167 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 85/500
#
# Epoch 85: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.0888 - accuracy: 0.9684 - val_loss: 0.2510 - val_accuracy: 0.9167 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 86/500
#
# Epoch 86: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1482 - accuracy: 0.9452 - val_loss: 0.4963 - val_accuracy: 0.8457 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 87/500
#
# Epoch 87: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.2292 - accuracy: 0.9174 - val_loss: 0.3877 - val_accuracy: 0.8611 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 88/500
#
# Epoch 88: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1208 - accuracy: 0.9637 - val_loss: 0.2647 - val_accuracy: 0.9074 - lr: 0.0010 - 1s/epoch - 32ms/step
# Epoch 89/500
#
# Epoch 89: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1020 - accuracy: 0.9614 - val_loss: 0.2975 - val_accuracy: 0.8796 - lr: 0.0010 - 1s/epoch - 31ms/step
# Epoch 90/500
#
# Epoch 90: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1052 - accuracy: 0.9637 - val_loss: 0.2421 - val_accuracy: 0.8981 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 91/500
#
# Epoch 91: val_accuracy did not improve from 0.91667
# 41/41 - 1s - loss: 0.1347 - accuracy: 0.9560 - val_loss: 0.3803 - val_accuracy: 0.8426 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 92/500
#
# Epoch 92: val_accuracy did not improve from 0.91667
# 41/41 - 2s - loss: 0.1299 - accuracy: 0.9537 - val_loss: 0.2488 - val_accuracy: 0.9074 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 93/500
#
# Epoch 93: val_accuracy improved from 0.91667 to 0.91975, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.1103 - accuracy: 0.9622 - val_loss: 0.1799 - val_accuracy: 0.9198 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 94/500
#
# Epoch 94: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.1320 - accuracy: 0.9537 - val_loss: 0.3109 - val_accuracy: 0.8951 - lr: 0.0010 - 996ms/epoch - 24ms/step
# Epoch 95/500
#
# Epoch 95: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.1689 - accuracy: 0.9414 - val_loss: 0.2580 - val_accuracy: 0.9105 - lr: 0.0010 - 1s/epoch - 26ms/step
# Epoch 96/500
#
# Epoch 96: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.1158 - accuracy: 0.9599 - val_loss: 0.2395 - val_accuracy: 0.9074 - lr: 0.0010 - 892ms/epoch - 22ms/step
# Epoch 97/500
#
# Epoch 97: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.0982 - accuracy: 0.9676 - val_loss: 0.2308 - val_accuracy: 0.9043 - lr: 0.0010 - 934ms/epoch - 23ms/step
# Epoch 98/500
#
# Epoch 98: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.0882 - accuracy: 0.9691 - val_loss: 0.2739 - val_accuracy: 0.8951 - lr: 0.0010 - 863ms/epoch - 21ms/step
# Epoch 99/500
#
# Epoch 99: val_accuracy did not improve from 0.91975
# 41/41 - 1s - loss: 0.0920 - accuracy: 0.9722 - val_loss: 0.2437 - val_accuracy: 0.9105 - lr: 0.0010 - 971ms/epoch - 24ms/step
# Epoch 100/500
#
# Epoch 100: val_accuracy improved from 0.91975 to 0.92284, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.2056 - val_accuracy: 0.9228 - lr: 0.0010 - 946ms/epoch - 23ms/step
# Epoch 101/500
#
# Epoch 101: val_accuracy did not improve from 0.92284
# 41/41 - 1s - loss: 0.0883 - accuracy: 0.9715 - val_loss: 0.2204 - val_accuracy: 0.9105 - lr: 0.0010 - 928ms/epoch - 23ms/step
# Epoch 102/500
#
# Epoch 102: val_accuracy improved from 0.92284 to 0.92593, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.0890 - accuracy: 0.9684 - val_loss: 0.2020 - val_accuracy: 0.9259 - lr: 0.0010 - 1s/epoch - 26ms/step
# Epoch 103/500
#
# Epoch 103: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0883 - accuracy: 0.9707 - val_loss: 0.2436 - val_accuracy: 0.9074 - lr: 0.0010 - 980ms/epoch - 24ms/step
# Epoch 104/500
#
# Epoch 104: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0632 - accuracy: 0.9792 - val_loss: 0.2339 - val_accuracy: 0.9167 - lr: 0.0010 - 1s/epoch - 30ms/step
# Epoch 105/500
#
# Epoch 105: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0699 - accuracy: 0.9784 - val_loss: 0.3536 - val_accuracy: 0.8827 - lr: 0.0010 - 909ms/epoch - 22ms/step
# Epoch 106/500
#
# Epoch 106: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1068 - accuracy: 0.9622 - val_loss: 0.2398 - val_accuracy: 0.8981 - lr: 0.0010 - 880ms/epoch - 21ms/step
# Epoch 107/500
#
# Epoch 107: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1185 - accuracy: 0.9583 - val_loss: 0.2497 - val_accuracy: 0.9043 - lr: 0.0010 - 926ms/epoch - 23ms/step
# Epoch 108/500
#
# Epoch 108: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0649 - accuracy: 0.9823 - val_loss: 0.2390 - val_accuracy: 0.9167 - lr: 0.0010 - 861ms/epoch - 21ms/step
# Epoch 109/500
#
# Epoch 109: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0847 - accuracy: 0.9699 - val_loss: 0.3025 - val_accuracy: 0.9105 - lr: 0.0010 - 882ms/epoch - 22ms/step
# Epoch 110/500
#
# Epoch 110: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0853 - accuracy: 0.9730 - val_loss: 0.2670 - val_accuracy: 0.9228 - lr: 0.0010 - 891ms/epoch - 22ms/step
# Epoch 111/500
#
# Epoch 111: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1237 - accuracy: 0.9591 - val_loss: 0.5346 - val_accuracy: 0.8395 - lr: 0.0010 - 910ms/epoch - 22ms/step
# Epoch 112/500
#
# Epoch 112: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1617 - accuracy: 0.9444 - val_loss: 0.4868 - val_accuracy: 0.8580 - lr: 0.0010 - 845ms/epoch - 21ms/step
# Epoch 113/500
#
# Epoch 113: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1563 - accuracy: 0.9460 - val_loss: 0.2852 - val_accuracy: 0.8981 - lr: 0.0010 - 861ms/epoch - 21ms/step
# Epoch 114/500
#
# Epoch 114: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1203 - accuracy: 0.9552 - val_loss: 0.2322 - val_accuracy: 0.9136 - lr: 0.0010 - 882ms/epoch - 22ms/step
# Epoch 115/500
#
# Epoch 115: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0745 - accuracy: 0.9769 - val_loss: 0.2274 - val_accuracy: 0.9136 - lr: 0.0010 - 980ms/epoch - 24ms/step
# Epoch 116/500
#
# Epoch 116: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.1075 - accuracy: 0.9630 - val_loss: 0.3082 - val_accuracy: 0.8796 - lr: 0.0010 - 1s/epoch - 28ms/step
# Epoch 117/500
#
# Epoch 117: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0947 - accuracy: 0.9699 - val_loss: 0.2322 - val_accuracy: 0.9259 - lr: 0.0010 - 902ms/epoch - 22ms/step
# Epoch 118/500
#
# Epoch 118: val_accuracy did not improve from 0.92593
# 41/41 - 1s - loss: 0.0630 - accuracy: 0.9776 - val_loss: 0.2763 - val_accuracy: 0.9167 - lr: 0.0010 - 860ms/epoch - 21ms/step
# Epoch 119/500
#
# Epoch 119: val_accuracy improved from 0.92593 to 0.93210, saving model to best_model_cnn.h5
# 41/41 - 1s - loss: 0.0649 - accuracy: 0.9799 - val_loss: 0.2116 - val_accuracy: 0.9321 - lr: 0.0010 - 903ms/epoch - 22ms/step
# Epoch 120/500
#
# Epoch 120: val_accuracy did not improve from 0.93210
# 41/41 - 1s - loss: 0.0697 - accuracy: 0.9815 - val_loss: 0.3161 - val_accuracy: 0.9167 - lr: 0.0010 - 867ms/epoch - 21ms/step
# Epoch 121/500
#
# Epoch 121: val_accuracy did not improve from 0.93210
# 41/41 - 1s - loss: 0.0779 - accuracy: 0.9738 - val_loss: 0.2632 - val_accuracy: 0.9167 - lr: 0.0010 - 907ms/epoch - 22ms/step
# Epoch 122/500
#
# Epoch 122: val_accuracy did not improve from 0.93210
# 41/41 - 1s - loss: 0.0689 - accuracy: 0.9753 - val_loss: 0.2149 - val_accuracy: 0.9228 - lr: 0.0010 - 855ms/epoch - 21ms/step
# Epoch 123/500
#
# Epoch 123: val_accuracy did not improve from 0.93210
# 41/41 - 1s - loss: 0.0873 - accuracy: 0.9707 - val_loss: 0.2644 - val_accuracy: 0.9105 - lr: 0.0010 - 849ms/epoch - 21ms/step
# Epoch 123: early stopping

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Plot the training history
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Task 2: Evaluating the performance of trained model on the testset

# %% [markdown]
# ### 2.1. Predict the label (which class) for each input image in the testset

# %%
output_test = model_cnn.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 9ms/step

# %%
pred_test = np.argmax(output_test,axis=-1)
truth_test = np.argmax(y_test,axis=-1)

# %%
# Visualize the first 30 test samples and show their predicted digit value in the title.
_,axes = plt.subplots(nrows = 3,ncols = 10, figsize= (10,5))
for r in range(3):
    for c in range(10):
        index = r*10 + c
        axes[r,c].set_axis_off()
        image = X_test[index].reshape((width,height))
        pred_label = pred_test[index]
        true_label = truth_test[index]
        axes[r,c].imshow(image, cmap = plt.cm.gray_r, interpolation = "nearest")
        if pred_label == true_label:
            axes[r,c].set_title(f"Pred.: {pred_label}\nTruth: {true_label}")
        else:
            axes[r,c].set_title(f"Pred.: {pred_label}\nTruth: {true_label}",color = 'red')

# %% [markdown]
# ### 2.2. Compute the metrics (quantitative measurements)

# %%
nb_classes = len(np.unique(truth_test))
## Visual bar plot of number occurrences of each class in testset:
statistic_class = np.unique(truth_test,return_counts=True)
categoricalClasses = [f'{C}' for C in statistic_class[0]]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.bar(x = categoricalClasses, height = statistic_class[1],width = 0.8)
for i in range(nb_classes):
    ax.text(categoricalClasses[i],statistic_class[1][i],
            str(statistic_class[1][i]),ha='center',va = 'bottom')
fig.suptitle("Number occurrences of each class on test set")
# Out:
# Text(0.5, 0.98, 'Number occurrences of each class on test set')

# %%
# Classification report:
print(f"Classification report for classifier {model_cnn}:\n"
      f"{metrics.classification_report(truth_test,pred_test,digits=4)}\n")
# Out:
# Classification report for classifier <keras.engine.sequential.Sequential object at 0x1320d9f90>:
#               precision    recall  f1-score   support
#
#            0     0.9714    0.9714    0.9714        35
#            1     0.9630    0.8125    0.8814        32
#            2     1.0000    1.0000    1.0000        21
#            3     0.7692    0.9091    0.8333        33
#            4     0.8667    1.0000    0.9286        26
#            5     1.0000    0.8485    0.9180        33
#
#     accuracy                         0.9167       180
#    macro avg     0.9284    0.9236    0.9221       180
# weighted avg     0.9263    0.9167    0.9175       180

# %%
# Confusion matrix
disp = metrics.ConfusionMatrixDisplay.from_predictions(truth_test,pred_test)
disp.figure_.suptitle("Confusion Matrix")
# print(f"Confusion matrix:\n{disp.confusion_matrix}")
plt.show()

# %% [markdown]
# ## 3. Task 3: Training model with data_augmentation, save and load the trained model

# %% [markdown]
# ### 3.1. Training model with data_augmentation

# %%
# Define the train data generator and validation data generator
train_datagen = ImageDataGenerator(
    rotation_range=8,
    height_shift_range=0.08,
    width_shift_range=0.08,
    shear_range=0.3,
    zoom_range=0.08,
    horizontal_flip=True,
    fill_mode='nearest'
)
validation_datagen = ImageDataGenerator()
train_generator = train_datagen.flow(
    x = X_train,
    y = y_train,
    batch_size = 32
)
val_generator = validation_datagen.flow(
    x = X_val,
    y = y_val,
    batch_size=32
)

# %%
# Define EarlyStopping, ModelCheckpoint, ReduceLearningRateOnPlateau.
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   verbose=1,
                   patience=30)
mc = ModelCheckpoint('best_model_cnn_datagen.h5',
                     monitor='val_accuracy',
                     mode='max',
                     verbose=1,
                     save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=30,
                              min_lr=0.0001,
                              mode = 'min')

# %%
# Training model with data generator
epochs = 500
optimizer = keras.optimizers.Adam()
loss = keras.losses.categorical_crossentropy
q_metrics = ['accuracy']
model_cnn.compile(optimizer=optimizer,
                   loss = loss,
                   metrics=q_metrics)

history_gen = model_cnn.fit_generator(
            train_generator,
            steps_per_epoch = len(X_train)//32,
            epochs = epochs,
            verbose = 1,
            validation_data = val_generator,
            validation_steps = len(X_val)//32,
            use_multiprocessing=False,
            callbacks = [es,mc,reduce_lr]
        )
# Out:
# Epoch 1/500
# /var/folders/pr/m0clhjz90k976cml329f7j740000gn/T/ipykernel_42925/4065036658.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_gen = model_cnn.fit_generator(
# 40/40 [==============================] - ETA: 0s - loss: 1.7698 - accuracy: 0.1859
# Epoch 1: val_accuracy improved from -inf to 0.27812, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 3s 58ms/step - loss: 1.7698 - accuracy: 0.1859 - val_loss: 1.7330 - val_accuracy: 0.2781 - lr: 0.0010
# Epoch 2/500
# 39/40 [============================>.] - ETA: 0s - loss: 1.5937 - accuracy: 0.3003
# Epoch 2: val_accuracy improved from 0.27812 to 0.33125, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 34ms/step - loss: 1.5945 - accuracy: 0.2951 - val_loss: 1.5017 - val_accuracy: 0.3313 - lr: 0.0010
# Epoch 3/500
# 40/40 [==============================] - ETA: 0s - loss: 1.2603 - accuracy: 0.4739
# Epoch 3: val_accuracy improved from 0.33125 to 0.49687, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 36ms/step - loss: 1.2603 - accuracy: 0.4739 - val_loss: 1.2040 - val_accuracy: 0.4969 - lr: 0.0010
# Epoch 4/500
# 40/40 [==============================] - ETA: 0s - loss: 1.0330 - accuracy: 0.5957
# Epoch 4: val_accuracy improved from 0.49687 to 0.51562, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 31ms/step - loss: 1.0330 - accuracy: 0.5957 - val_loss: 1.2641 - val_accuracy: 0.5156 - lr: 0.0010
# Epoch 5/500
# 39/40 [============================>.] - ETA: 0s - loss: 1.0216 - accuracy: 0.6169
# Epoch 5: val_accuracy improved from 0.51562 to 0.64375, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 35ms/step - loss: 1.0233 - accuracy: 0.6155 - val_loss: 1.0852 - val_accuracy: 0.6438 - lr: 0.0010
# Epoch 6/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.9513 - accuracy: 0.6388
# Epoch 6: val_accuracy did not improve from 0.64375
# 40/40 [==============================] - 1s 32ms/step - loss: 0.9470 - accuracy: 0.6408 - val_loss: 1.1323 - val_accuracy: 0.5094 - lr: 0.0010
# Epoch 7/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.9121 - accuracy: 0.6485
# Epoch 7: val_accuracy improved from 0.64375 to 0.70625, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 33ms/step - loss: 0.9066 - accuracy: 0.6511 - val_loss: 0.9345 - val_accuracy: 0.7063 - lr: 0.0010
# Epoch 8/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.8478 - accuracy: 0.7062
# Epoch 8: val_accuracy did not improve from 0.70625
# 40/40 [==============================] - 2s 38ms/step - loss: 0.8494 - accuracy: 0.7049 - val_loss: 1.0367 - val_accuracy: 0.6344 - lr: 0.0010
# Epoch 9/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.8154 - accuracy: 0.7102
# Epoch 9: val_accuracy did not improve from 0.70625
# 40/40 [==============================] - 1s 34ms/step - loss: 0.8114 - accuracy: 0.7104 - val_loss: 0.8767 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 10/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.7832 - accuracy: 0.7110
# Epoch 10: val_accuracy did not improve from 0.70625
# 40/40 [==============================] - 2s 38ms/step - loss: 0.7848 - accuracy: 0.7073 - val_loss: 0.9739 - val_accuracy: 0.6187 - lr: 0.0010
# Epoch 11/500
# 40/40 [==============================] - ETA: 0s - loss: 0.7686 - accuracy: 0.7421
# Epoch 11: val_accuracy did not improve from 0.70625
# 40/40 [==============================] - 2s 37ms/step - loss: 0.7686 - accuracy: 0.7421 - val_loss: 0.8527 - val_accuracy: 0.6906 - lr: 0.0010
# Epoch 12/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.7491 - accuracy: 0.7346
# Epoch 12: val_accuracy improved from 0.70625 to 0.75000, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 32ms/step - loss: 0.7494 - accuracy: 0.7334 - val_loss: 0.8275 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/500
# 40/40 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.7570
# Epoch 13: val_accuracy did not improve from 0.75000
# 40/40 [==============================] - 2s 39ms/step - loss: 0.6901 - accuracy: 0.7570 - val_loss: 0.8807 - val_accuracy: 0.6656 - lr: 0.0010
# Epoch 14/500
# 40/40 [==============================] - ETA: 0s - loss: 0.7946 - accuracy: 0.6875
# Epoch 14: val_accuracy did not improve from 0.75000
# 40/40 [==============================] - 2s 49ms/step - loss: 0.7946 - accuracy: 0.6875 - val_loss: 0.9275 - val_accuracy: 0.6219 - lr: 0.0010
# Epoch 15/500
# 39/40 [============================>.] - ETA: 0s - loss: 0
- val_accuracy: 0.8281 - lr: 0.0010
# Epoch 31/500
# 40/40 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.8441
# Epoch 31: val_accuracy did not improve from 0.83125
# 40/40 [==============================] - 1s 30ms/step - loss: 0.4267 - accuracy: 0.8441 - val_loss: 0.4953 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 32/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3724 - accuracy: 0.8669
# Epoch 32: val_accuracy improved from 0.83125 to 0.84062, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 2s 40ms/step - loss: 0.3720 - accuracy: 0.8671 - val_loss: 0.4444 - val_accuracy: 0.8406 - lr: 0.0010
# Epoch 33/500
# 40/40 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.8426
# Epoch 33: val_accuracy improved from 0.84062 to 0.85000, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 34ms/step - loss: 0.4354 - accuracy: 0.8426 - val_loss: 0.4338 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 34/500
# 40/40 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8481
# Epoch 34: val_accuracy improved from 0.85000 to 0.85625, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 31ms/step - loss: 0.4060 - accuracy: 0.8481 - val_loss: 0.3999 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 35/500
# 40/40 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8821
# Epoch 35: val_accuracy did not improve from 0.85625
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3350 - accuracy: 0.8821 - val_loss: 0.4225 - val_accuracy: 0.8375 - lr: 0.0010
# Epoch 36/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3620 - accuracy: 0.8807
# Epoch 36: val_accuracy did not improve from 0.85625
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3617 - accuracy: 0.8797 - val_loss: 0.5058 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 37/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8677
# Epoch 37: val_accuracy improved from 0.85625 to 0.87187, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 32ms/step - loss: 0.3705 - accuracy: 0.8687 - val_loss: 0.3727 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 38/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3737 - accuracy: 0.8653
# Epoch 38: val_accuracy did not improve from 0.87187
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3762 - accuracy: 0.8639 - val_loss: 0.4241 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 39/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3718 - accuracy: 0.8677
# Epoch 39: val_accuracy did not improve from 0.87187
# 40/40 [==============================] - 1s 31ms/step - loss: 0.3722 - accuracy: 0.8663 - val_loss: 0.5126 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 40/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3560 - accuracy: 0.8742
# Epoch 40: val_accuracy did not improve from 0.87187
# 40/40 [==============================] - 2s 41ms/step - loss: 0.3600 - accuracy: 0.8726 - val_loss: 0.3353 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 41/500
# 40/40 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8979
# Epoch 41: val_accuracy did not improve from 0.87187
# 40/40 [==============================] - 1s 32ms/step - loss: 0.3099 - accuracy: 0.8979 - val_loss: 0.3675 - val_accuracy: 0.8687 - lr: 0.0010
# Epoch 42/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2998 - accuracy: 0.8969
# Epoch 42: val_accuracy improved from 0.87187 to 0.88125, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3003 - accuracy: 0.8972 - val_loss: 0.3268 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 43/500
# 40/40 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8908
# Epoch 43: val_accuracy did not improve from 0.88125
# 40/40 [==============================] - 1s 32ms/step - loss: 0.3107 - accuracy: 0.8908 - val_loss: 0.4378 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 44/500
# 40/40 [==============================] - ETA: 0s - loss: 0.3035 - accuracy: 0.8932
# Epoch 44: val_accuracy did not improve from 0.88125
# 40/40 [==============================] - 2s 37ms/step - loss: 0.3035 - accuracy: 0.8932 - val_loss: 0.3462 - val_accuracy: 0.8625 - lr: 0.0010
# Epoch 45/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2891 - accuracy: 0.8961
# Epoch 45: val_accuracy did not improve from 0.88125
# 40/40 [==============================] - 1s 33ms/step - loss: 0.2893 - accuracy: 0.8972 - val_loss: 0.4027 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 46/500
# 40/40 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.8750
# Epoch 46: val_accuracy did not improve from 0.88125
# 40/40 [==============================] - 1s 32ms/step - loss: 0.3427 - accuracy: 0.8750 - val_loss: 0.4123 - val_accuracy: 0.8375 - lr: 0.0010
# Epoch 47/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3100 - accuracy: 0.8953
# Epoch 47: val_accuracy improved from 0.88125 to 0.88437, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s
saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2155 - accuracy: 0.9312 - val_loss: 0.2759 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 72/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9320
# Epoch 72: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 1s 34ms/step - loss: 0.1943 - accuracy: 0.9320 - val_loss: 0.3487 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 73/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9074
# Epoch 73: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 1s 34ms/step - loss: 0.2430 - accuracy: 0.9074 - val_loss: 0.3358 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 74/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2493 - accuracy: 0.9156
# Epoch 74: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 1s 32ms/step - loss: 0.2465 - accuracy: 0.9161 - val_loss: 0.3348 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 75/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9446
# Epoch 75: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 2s 42ms/step - loss: 0.1929 - accuracy: 0.9446 - val_loss: 0.3044 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 76/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2404 - accuracy: 0.9067
# Epoch 76: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 1s 33ms/step - loss: 0.2391 - accuracy: 0.9066 - val_loss: 0.3725 - val_accuracy: 0.8656 - lr: 0.0010
# Epoch 77/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.9263
# Epoch 77: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 2s 41ms/step - loss: 0.2296 - accuracy: 0.9248 - val_loss: 0.2892 - val_accuracy: 0.8938 - lr: 0.0010
# Epoch 78/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9051
# Epoch 78: val_accuracy did not improve from 0.90625
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2424 - accuracy: 0.9051 - val_loss: 0.5840 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 79/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9156
# Epoch 79: val_accuracy improved from 0.90625 to 0.90938, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 33ms/step - loss: 0.2544 - accuracy: 0.9138 - val_loss: 0.2517 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 80/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.9115
# Epoch 80: val_accuracy did not improve from 0.90938
# 40/40 [==============================] - 1s 33ms/step - loss: 0.2522 - accuracy: 0.9114 - val_loss: 0.3431 - val_accuracy: 0.8781 - lr: 0.0010
# Epoch 81/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2396 - accuracy: 0.9205
# Epoch 81: val_accuracy did not improve from 0.90938
# 40/40 [==============================] - 2s 40ms/step - loss: 0.2406 - accuracy: 0.9193 - val_loss: 0.3054 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 82/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2294 - accuracy: 0.9180
# Epoch 82: val_accuracy did not improve from 0.90938
# 40/40 [==============================] - 1s 34ms/step - loss: 0.2334 - accuracy: 0.9169 - val_loss: 0.3295 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 83/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9177
# Epoch 83: val_accuracy did not improve from 0.90938
# 40/40 [==============================] - 2s 41ms/step - loss: 0.2286 - accuracy: 0.9177 - val_loss: 0.2923 - val_accuracy: 0.8938 - lr: 0.0010
# Epoch 84/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1949 - accuracy: 0.9318
# Epoch 84: val_accuracy did not improve from 0.90938
# 40/40 [==============================] - 2s 40ms/step - loss: 0.1956 - accuracy: 0.9312 - val_loss: 0.2544 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 85/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9304
# Epoch 85: val_accuracy improved from 0.90938 to 0.91562, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 34ms/step - loss: 0.1933 - accuracy: 0.9304 - val_loss: 0.2446 - val_accuracy: 0.9156 - lr: 0.0010
# Epoch 86/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1900 - accuracy: 0.9359
# Epoch 86: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 36ms/step - loss: 0.1941 - accuracy: 0.9343 - val_loss: 0.2946 - val_accuracy: 0.8781 - lr: 0.0010
# Epoch 87/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2030 - accuracy: 0.9294
# Epoch 87: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 30ms/step - loss: 0.2011 - accuracy: 0.9296 - val_loss: 0.3564 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 88/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9234
# Epoch 88: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1987 - accuracy: 0.9234 - val_loss: 0.3043 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 89/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9098
# Epoch 89: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2296 - accuracy: 0.9098 - val_loss: 0.3273 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 90/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2083 - accuracy: 0.9253
# Epoch 90: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 30ms/step - loss: 0.2047 - accuracy: 0.9272 - val_loss: 0.3030 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 91/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2091 - accuracy: 0.9253
# Epoch 91: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 32ms/step - loss: 0.2072 - accuracy: 0.9264 - val_loss: 0.2751 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 92/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9296
# Epoch 92: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 36ms/step - loss: 0.1886 - accuracy: 0.9296 - val_loss: 0.2965 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 93/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9383
# Epoch 93: val_accuracy did not improve from 0.91562
# 40/40 [==============================] - 1s 33ms/step - loss: 0.1837 - accuracy: 0.9383 - val_loss: 0.2445 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 94/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1814 - accuracy: 0.9359
# Epoch 94: val_accuracy improved from 0.91562 to 0.92188, saving model to best_model_cnn_datagen.h5
# 40/40 [==============================] - 1s 36ms/step - loss: 0.1778 - accuracy: 0.9375 - val_loss: 0.2144 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 95/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1394 - accuracy: 0.9472
# Epoch 95: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1462 - accuracy: 0.9454 - val_loss: 0.2664 - val_accuracy: 0.8969 - lr: 0.0010
# Epoch 96/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9161
# Epoch 96: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 34ms/step - loss: 0.2316 - accuracy: 0.9161 - val_loss: 0.3415 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 97/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9225
# Epoch 97: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2206 - accuracy: 0.9225 - val_loss: 0.3186 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 98/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.9383
# Epoch 98: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1647 - accuracy: 0.9383 - val_loss: 0.2475 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 99/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9343
# Epoch 99: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 36ms/step - loss: 0.1960 - accuracy: 0.9343 - val_loss: 0.3543 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 100/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.9302
# Epoch 100: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2078 - accuracy: 0.9288 - val_loss: 0.3887 - val_accuracy: 0.8656 - lr: 0.0010
# Epoch 101/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1826 - accuracy: 0.9367
# Epoch 101: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 33ms/step - loss: 0.1826 - accuracy: 0.9367 - val_loss: 0.3092 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 102/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9312
# Epoch 102: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 35ms/step - loss: 0.1936 - accuracy: 0.9312 - val_loss: 0.2481 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 103/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.3279 - accuracy: 0.8782
# Epoch 103: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.3277 - accuracy: 0.8782 - val_loss: 0.3240 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 104/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2019 - accuracy: 0.9367
# Epoch 104: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 34ms/step - loss: 0.2019 - accuracy: 0.9367 - val_loss: 0.2860 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 105/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9438
# Epoch 105: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 34ms/step - loss: 0.1585 - accuracy: 0.9438 - val_loss: 0.2508 - val_accuracy: 0.9187 - lr: 0.0010
# Epoch 106/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9502
# Epoch 106: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1605 - accuracy: 0.9502 - val_loss: 0.2581 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 107/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9438
# Epoch 107: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 34ms/step - loss: 0.1734 - accuracy: 0.9438 - val_loss: 0.2710 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 108/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9343
# Epoch 108: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1661 - accuracy: 0.9343 - val_loss: 0.2174 - val_accuracy: 0.9156 - lr: 0.0010
# Epoch 109/500
# 40/40 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.8908
# Epoch 109: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2962 - accuracy: 0.8908 - val_loss: 0.3792 - val_accuracy: 0.8687 - lr: 0.0010
# Epoch 110/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9328
# Epoch 110: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1977 - accuracy: 0.9328 - val_loss: 0.2852 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 111/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.2225 - accuracy: 0.9188
# Epoch 111: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.2212 - accuracy: 0.9185 - val_loss: 0.2834 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 112/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9525
# Epoch 112: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 34ms/step - loss: 0.1462 - accuracy: 0.9525 - val_loss: 0.2435 - val_accuracy: 0.9125 - lr: 0.0010
# Epoch 113/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9430
# Epoch 113: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1453 - accuracy: 0.9430 - val_loss: 0.4322 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 114/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1682 - accuracy: 0.9416
# Epoch 114: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1730 - accuracy: 0.9399 - val_loss: 0.2913 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 115/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1742 - accuracy: 0.9407
# Epoch 115: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 32ms/step - loss: 0.1721 - accuracy: 0.9415 - val_loss: 0.2704 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 116/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9440
# Epoch 116: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1589 - accuracy: 0.9438 - val_loss: 0.2144 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 117/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9351
# Epoch 117: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 36ms/step - loss: 0.1929 - accuracy: 0.9351 - val_loss: 0.3291 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 118/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9367
# Epoch 118: val_accuracy did not improve from 0.92188
# 40/40 [==============================] - 1s 31ms/step - loss: 0.
val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0915 - accuracy: 0.9684 - val_loss: 0.1710 - val_accuracy: 0.9312 - lr: 1.0000e-04
# Epoch 219/500
# 40/40 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9644
# Epoch 219: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0971 - accuracy: 0.9644 - val_loss: 0.1803 - val_accuracy: 0.9344 - lr: 1.0000e-04
# Epoch 220/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.0937 - accuracy: 0.9724
# Epoch 220: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0922 - accuracy: 0.9731 - val_loss: 0.1847 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 221/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9619
# Epoch 221: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 2s 37ms/step - loss: 0.1027 - accuracy: 0.9628 - val_loss: 0.2082 - val_accuracy: 0.9187 - lr: 1.0000e-04
# Epoch 222/500
# 40/40 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9636
# Epoch 222: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 35ms/step - loss: 0.1030 - accuracy: 0.9636 - val_loss: 0.1799 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 223/500
# 40/40 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9676
# Epoch 223: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0991 - accuracy: 0.9676 - val_loss: 0.1744 - val_accuracy: 0.9281 - lr: 1.0000e-04
# Epoch 224/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9675
# Epoch 224: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0964 - accuracy: 0.9668 - val_loss: 0.1884 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 225/500
# 39/40 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9675
# Epoch 225: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0895 - accuracy: 0.9684 - val_loss: 0.2114 - val_accuracy: 0.9094 - lr: 1.0000e-04
# Epoch 226/500
# 40/40 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9684
# Epoch 226: val_accuracy did not improve from 0.94063
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0945 - accuracy: 0.9684 - val_loss: 0.1940 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 226: early stopping

# %%
accuracy = history_gen.history['accuracy']
val_accuracy = history_gen.history['val_accuracy']
loss = history_gen.history['loss']
val_loss = history_gen.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 3.2 Loading the trained model and evaluating on the test set
# We have named the best model during the training process with data generator as "best_model_cnn_datagen.h5"

# %%
trained_model_dir = "/Users/user/AI_Class/P4_DeepLearning/S2_CovolutionalNN/best_model_cnn_datagen.h5"
load_model = keras.models.load_model(trained_model_dir)

# %%
load_model_output_test = load_model.predict(X_test)
load_model_pred_test = np.argmax(load_model_output_test,axis=1)
# Out:
# 6/6 [==============================] - 0s 6ms/step

# %%
# Visualize the first 30 test samples and show their predicted digit value in the title.
_,axes = plt.subplots(nrows = 3,ncols = 10, figsize= (10,5))
for r in range(3):
    for c in range(10):
        index = r*10 + c
        axes[r,c].set_axis_off()
        image = X_test[index].reshape((width,height))
        pred_label = load_model_pred_test[index]
        true_label = truth_test[index]
        axes[r,c].imshow(image, cmap = plt.cm.gray_r, interpolation = "nearest")
        if pred_label == true_label:
            axes[r,c].set_title(f"Pred.: {pred_label}\nTruth: {true_label}")
        else:
            axes[r,c].set_title(f"Pred.: {pred_label}\nTruth: {true_label}",color = 'red')

# %%
# Classification report:
print(f"Classification report for classifier {load_model}:\n"
      f"{metrics.classification_report(truth_test,load_model_pred_test,digits=4)}\n")
# Out:
# Classification report for classifier <keras.engine.sequential.Sequential object at 0x13210f9a0>:
#               precision    recall  f1-score   support
#
#            0     0.9722    1.0000    0.9859        35
#            1     0.9091    0.9375    0.9231        32
#            2     1.0000    1.0000    1.0000        21
#            3     0.8857    0.9394    0.9118        33
#            4     1.0000    1.0000    1.0000        26
#            5     1.0000    0.8788    0.9355        33
#
#     accuracy                         0.9556       180
#    macro avg     0.9612    0.9593    0.9594       180
# weighted avg     0.9575    0.9556    0.9556       180

# %%
# Confusion matrix
disp = metrics.ConfusionMatrixDisplay.from_predictions(truth_test,load_model_pred_test)
disp.figure_.suptitle("Confusion Matrix")
# print(f"Confusion matrix:\n{disp.confusion_matrix}")
plt.show()
