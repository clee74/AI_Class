# %% [markdown]
# # Demo 1: Gated Recurrent Unit (GRU)
#
# Gate Recurrent Unit (GRU) is a type of Recurrent Neural Network (RNN) that, in certain cases, has advantages over LSTM. GRU uses less memory and is faster than LSTM, however, LSTM is more accurate when using datasets with longer sequences.
#
# This demo we will demo code for construct a GRU model to solve the regression problem:
# -   Problem: Predict stock close price of Taiwan Semiconductor Manufacturing Company (TSMC) based on the stock close price of TSMC in previous period
# -   Dataset: Stock dataset which is getting from yahoo finance database by using the yfinance package.
# -   Library packages:
#     -   Yfinance (offers a threaded and Pythonic way to download market data from Yahoo finance)
#     -   Pandas (A fast and efficient dataframe object for data manipulation with integrated indexing, reading and writing data between in-memory data structures and different formats: CSV, Microsoft Excel, SQL databases)
#     -   Matplotlib (Plot package: visualize data, result,...)
#     -   TensorFlow (This is an open-source library that is used for DL/ML/AI)
#     -   Scikit-Learning (Machine Learning library)
#
# Tasks Outlines:
#
# ## 0. Task 0: Preparing dataset
# -   Getting the stock dataset of TSMC
# -   Exploring about the dataset
# -   Normalize or standardlize dataset
# -   Divide dataset to trainset and testset
# -   Construct data fir GRU model
# ## 1. Task 1: Constructing model by using TensorFlow library:
# -   Create a Gated Recurrent Unit model for regression problem
# -   Training model on our trainset and applying the model checkpoint during the training to save the best model
# ## 2. Task 2: Evaluating the performance of trained model on the testset
# -   Predict the price of stock
# -   Compute the metrics (quantitative measurements)
#     -   R2_score, Mean Absolute Error (MAE), Root MAE,...

# %% [markdown]
# ## Import all packages

# %%
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance
from matplotlib import pyplot as plt
import numpy as np

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %% [markdown]
# ## 0. Task 0: Preparing Dataset
#
# Go to the notebook file: Demo_data_stock_yfinance.ipynb to get detail of demo code for this step

# %% [markdown]
# ### 0.1. Getting stock data of TSMC with company Code: TSM from 2 years ago.

# %%
# Getting stock data of Company Name: TSMC with Company Code: TSM
"""
-   start_date: start time to getting data stock
-   end_data: end time to getting data stock
-   data_source: where to getting data
"""
now = datetime.now()
data_source = 'yahoo'
start_date = now.today() - relativedelta(years  = 2)
end_date = now.today()
print(start_date)
print(end_date)
df_TSM = yfinance.download("TSM",start=start_date,end=end_date)
# Out:
# 2021-12-26 23:18:23.610146
# 2023-12-26 23:18:23.610146
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### 0.2. Exploring the data:
# See the file Demo_data_stock_yfinance.ipynb for more detail.

# %%
# Type of data after getting from yfinance:
print(type(df_TSM))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Data info:
df_TSM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 503 entries, 2021-12-27 to 2023-12-26
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       503 non-null    float64
#  1   High       503 non-null    float64
#  2   Low        503 non-null    float64
#  3   Close      503 non-null    float64
#  4   Adj Close  503 non-null    float64
#  5   Volume     503 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 27.5 KB

# %%
# Showing most recently five days in our dataframe
df_TSM.tail(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-19  103.239998  103.980003  103.089996  103.870003  103.870003
# 2023-12-20  102.699997  103.089996   99.940002  100.040001  100.040001
# 2023-12-21  101.300003  102.720001  101.160004  102.550003  102.550003
# 2023-12-22  102.930000  103.589996  102.709999  103.150002  103.150002
# 2023-12-26  103.610001  104.957497  103.570000  104.809998  104.809998
#
#               Volume
# Date
# 2023-12-19   8498500
# 2023-12-20  10814100
# 2023-12-21   9068200
# 2023-12-22   5566400
# 2023-12-26   1305746

# %% [markdown]
# ### 0.3. Visualize data in stock form.

# %%
# Preparing data to plot: range of close open, range of low high, check close >= open for each day
df_TSM["Y_price"] = (df_TSM["Open"] + df_TSM["Close"])/2
df_TSM["Y_error"] = (df_TSM["Open"] - df_TSM["Close"]).abs()/2
df_TSM["HL"] = (df_TSM["High"] + df_TSM["Low"])/2
df_TSM["HL_error"] = (df_TSM["High"] - df_TSM["Low"]).abs()/2
df_TSM["IsPositive"] = df_TSM["Close"] >= df_TSM["Open"]

# %%
# We only plot most recently 100 days stock data of TSMC:
data_to_plot = df_TSM.tail(100)

# %%
# Visualize data
colors = {True:'red',False:'green'}

fig, ax = plt.subplots(1,1,figsize = (15,5))
# ax.plot(plot_df_TSM.index.tolist(),plot_df_TSM["Open"],color='g')
# ax.plot(plot_df_TSM.index.tolist(),plot_df_TSM["Close"],color='red')
""" 
The following line of code plot bar range open close, color base on
the comparision of open price and close price
"""
ax.errorbar(data_to_plot.index.tolist(),
            data_to_plot["Y_price"],
            data_to_plot["Y_error"],
            linewidth = 5, 
            capsize=0,
            ls='none',
            ecolor = data_to_plot['IsPositive'].map(colors))
"""
The following line of code plot black interval with the width = high - low
"""
ax.errorbar(data_to_plot.index.tolist(),
            data_to_plot["HL"],
            data_to_plot["HL_error"],
            linewidth = 1,
            capsize=3,
            color='k',
            ls='none')

fig.suptitle("Graph of open value with time value_open = f(date_time)")
ax.set_xlabel("Date_time")
ax.set_ylabel("Open")
ax.set_xticks(data_to_plot.index.tolist()[::5]) #Without this it is too dense, with this we only display every after 5 xticks
ax.set_xticklabels(ax.get_xticklabels(),rotation = 40, ha = 'center')# Shearing the labels to 40 degree and write it in center
plt.show()

# %% [markdown]
# ### 0.4. Prepare data for training model:
# -   We consider the Close column in our data set as timeseries data
# -   Divide data into two parts:
#     -   For training: first 400 rows
#     -   For testing: start from row 400th
# -   Creating a data structure with 60 timesteps and 1 ouput

# %%
train_data = df_TSM["Close"][:400].values
X_train = []
y_train = []
for i in range(60,400):
    X_train.append(train_data[i-60:i])
    y_train.append(train_data[i])
X_train,y_train = np.array(X_train),np.array(y_train)
# Reshaping 
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %%
X_train.shape
# Out:
# (340, 60, 1)

# %% [markdown]
# ## 1. Task 1: Constructing model by using TensorFlow library:
# ### 1.1. Creating GRU Network model
#
# Model with 3 GRU layers and one output layer

# %%
# Define the model GRU
model_GRU = Sequential()
## Adding the first GRU layer and some Dropout regularisation
model_GRU.add(GRU(units = 60,
                        return_sequences=True,
                        input_shape = (X_train.shape[1],1)))
model_GRU.add(Dropout(0.2))
## Adding the second GRU layer and some Dropout regularisation
model_GRU.add(GRU(units=50,
                        return_sequences=True))
model_GRU.add(Dropout(0.2))
## Adding the third GRU layer and some Dropout regularisation
model_GRU.add(GRU(units=50))
model_GRU.add(Dropout(0.2))

## Adding the output layer
model_GRU.add(Dense(units=1))

# %%
model_GRU.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 60, 60)            11340
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  gru_1 (GRU)                 (None, 60, 50)            16800
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 43,491
# Trainable params: 43,491
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.2. Training model on our trainset and applying the model checkpoint during the training

# %%
mc = ModelCheckpoint('model_GRU.h5',
                     monitor = 'loss',
                     mode = 'min',
                     verbose = 1,
                     save_best_only = True)

# %%
epochs = 1000
optimizer = keras.optimizers.Adam()
model_GRU.compile(optimizer=optimizer,
                  loss='mean_squared_error')
history = model_GRU.fit(X_train,y_train,
                        epochs = epochs, 
                        batch_size=32,
                        verbose = 2,
                        callbacks = [mc])
# Out:
# Epoch 1/1000
# Epoch 1: loss improved from inf to 42.71750, saving model to model_GRU.h5
# 11/11 - 9s - loss: 42.7175 - 9s/epoch - 850ms/step
# Epoch 2/1000
#
# Epoch 2: loss did not improve from 42.71750
# 11/11 - 1s - loss: 49.0519 - 1s/epoch - 111ms/step
# Epoch 3/1000
#
# Epoch 3: loss did not improve from 42.71750
# 11/11 - 1s - loss: 44.2359 - 1s/epoch - 106ms/step
# Epoch 4/1000
#
# Epoch 4: loss did not improve from 42.71750
# 11/11 - 1s - loss: 42.8676 - 1s/epoch - 110ms/step
# Epoch 5/1000
#
# Epoch 5: loss did not improve from 42.71750
# 11/11 - 1s - loss: 45.9014 - 1s/epoch - 105ms/step
# Epoch 6/1000
#
# Epoch 6: loss did not improve from 42.71750
# 11/11 - 1s - loss: 44.8698 - 1s/epoch - 103ms/step
# Epoch 7/1000
#
# Epoch 7: loss did not improve from 42.71750
# 11/11 - 1s - loss: 53.0015 - 1s/epoch - 106ms/step
# Epoch 8/1000
#
# Epoch 8: loss did not improve from 42.71750
# 11/11 - 1s - loss: 44.2445 - 1s/epoch - 112ms/step
# Epoch 9/1000
#
# Epoch 9: loss did not improve from 42.71750
# 11/11 - 1s - loss: 48.5309 - 1s/epoch - 112ms/step
# Epoch 10/1000
#
# Epoch 10: loss did not improve from 42.71750
# 11/11 - 1s - loss: 49.6224 - 1s/epoch - 136ms/step
# Epoch 11/1000
#
# Epoch 11: loss improved from 42.71750 to 41.04481, saving model to model_GRU.h5
# 11/11 - 2s - loss: 41.0448 - 2s/epoch - 153ms/step
# Epoch 12/1000
#
# Epoch 12: loss did not improve from 41.04481
# 11/11 - 2s - loss: 45.8406 - 2s/epoch - 155ms/step
# Epoch 13/1000
#
# Epoch 13: loss did not improve from 41.04481
# 11/11 - 2s - loss: 43.2379 - 2s/epoch - 142ms/step
# Epoch 14/1000
#
# Epoch 14: loss did not improve from 41.04481
# 11/11 - 2s - loss: 44.2045 - 2s/epoch - 139ms/step
# Epoch 15/1000
#
# Epoch 15: loss did not improve from 41.04481
# 11/11 - 2s - loss: 42.1472 - 2s/epoch - 153ms/step
# Epoch 16/1000
#
# Epoch 16: loss did not improve from 41.04481
# 11/11 - 2s - loss: 46.1595 - 2s/epoch - 144ms/step
# Epoch 17/1000
#
# Epoch 17: loss did not improve from 41.04481
# 11/11 - 2s - loss: 47.8389 - 2s/epoch - 150ms/step
# Epoch 18/1000
#
# Epoch 18: loss did not improve from 41.04481
# 11/11 - 2s - loss: 42.8872 - 2s/epoch - 142ms/step
# Epoch 19/1000
#
# Epoch 19: loss did not improve from 41.04481
# 11/11 - 1s - loss: 50.5605 - 1s/epoch - 130ms/step
# Epoch 20/1000
#
# Epoch 20: loss did not improve from 41.04481
# 11/11 - 2s - loss: 50.9579 - 2s/epoch - 138ms/step
# Epoch 21/1000
#
# Epoch 21: loss did not improve from 41.04481
# 11/11 - 2s - loss: 53.9455 - 2s/epoch - 146ms/step
# Epoch 22/1000
#
# Epoch 22: loss did not improve from 41.04481
# 11/11 - 2s - loss: 49.1365 - 2s/epoch - 178ms/step
# Epoch 23/1000
#
# Epoch 23: loss did not improve from 41.04481
# 11/11 - 1s - loss: 46.2319 - 1s/epoch - 128ms/step
# Epoch 24/1000
#
# Epoch 24: loss did not improve from 41.04481
# 11/11 - 2s - loss: 52.1753 - 2s/epoch - 137ms/step
# Epoch 25/1000
#
# Epoch 25: loss improved from 41.04481 to 40.18837, saving model to model_GRU.h5
# 11/11 - 2s - loss: 40.1884 - 2s/epoch - 159ms/step
# Epoch 26/1000
#
# Epoch 26: loss did not improve from 40.18837
# 11/11 - 2s - loss: 47.8828 - 2s/epoch - 138ms/step
# Epoch 27/1000
#
# Epoch 27: loss did not improve from 40.18837
# 11/11 - 2s - loss: 45.4832 - 2s/epoch - 141ms/step
# Epoch 28/1000
#
# Epoch 28: loss did not improve from 40.18837
# 11/11 - 2s - loss: 42.7153 - 2s/epoch - 157ms/step
# Epoch 29/1000
#
# Epoch 29: loss did not improve from 40.18837
# 11/11 - 1s - loss: 47.9998 - 1s/epoch - 135ms/step
# Epoch 30/1000
#
# Epoch 30: loss did not improve from 40.18837
# 11/11 - 2s - loss: 45.4948 - 2s/epoch - 146ms/step
# Epoch 31/1000
#
# Epoch 31: loss did not improve from 40.18837
# 11/11 - 2s - loss: 50.6454 - 2s/epoch - 152ms/step
# Epoch 32/1000
#
# Epoch 32: loss did not improve from 40.18837
# 11/11 - 2s - loss: 42.4745 - 2s/epoch - 137ms/step
# Epoch 33/1000
#
# Epoch 33: loss improved from 40.18837 to 37.26779, saving model to model_GRU.h5
# 11/11 - 2s - loss: 37.2678 - 2s/epoch - 153ms/step
# Epoch 34/1000
#
# Epoch 34: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.8003 - 2s/epoch - 156ms/step
# Epoch 35/1000
#
# Epoch 35: loss did not improve from 37.26779
# 11/11 - 1s - loss: 38.3289 - 1s/epoch - 135ms/step
# Epoch 36/1000
#
# Epoch 36: loss did not improve from 37.26779
# 11/11 - 1s - loss: 47.3428 - 1s/epoch - 135ms/step
# Epoch 37/1000
#
# Epoch 37: loss did not improve from 37.26779
# 11/11 - 2s - loss: 48.2443 - 2s/epoch - 146ms/step
# Epoch 38/1000
#
# Epoch 38: loss did not improve from 37.26779
# 11/11 - 2s - loss: 42.5146 - 2s/epoch - 138ms/step
# Epoch 39/1000
#
# Epoch 39: loss did not improve from 37.26779
# 11/11 - 1s - loss: 43.3683 - 1s/epoch - 133ms/step
# Epoch 40/1000
#
# Epoch 40: loss did not improve from 37.26779
# 11/11 - 2s - loss: 37.6321 - 2s/epoch - 140ms/step
# Epoch 41/1000
#
# Epoch 41: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.6956 - 2s/epoch - 140ms/step
# Epoch 42/1000
#
# Epoch 42: loss did not improve from 37.26779
# 11/11 - 2s - loss: 52.6978 - 2s/epoch - 137ms/step
# Epoch 43/1000
#
# Epoch 43: loss did not improve from 37.26779
# 11/11 - 2s - loss: 49.0512 - 2s/epoch - 153ms/step
# Epoch 44/1000
#
# Epoch 44: loss did not improve from 37.26779
# 11/11 - 2s - loss: 47.5220 - 2s/epoch - 144ms/step
# Epoch 45/1000
#
# Epoch 45: loss did not improve from 37.26779
# 11/11 - 1s - loss: 45.0408 - 1s/epoch - 133ms/step
# Epoch 46/1000
#
# Epoch 46: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.0751 - 2s/epoch - 143ms/step
# Epoch 47/1000
#
# Epoch 47: loss did not improve from 37.26779
# 11/11 - 2s - loss: 42.7949 - 2s/epoch - 140ms/step
# Epoch 48/1000
#
# Epoch 48: loss did not improve from 37.26779
# 11/11 - 1s - loss: 45.1982 - 1s/epoch - 133ms/step
# Epoch 49/1000
#
# Epoch 49: loss did not improve from 37.26779
# 11/11 - 1s - loss: 42.5711 - 1s/epoch - 126ms/step
# Epoch 50/1000
#
# Epoch 50: loss did not improve from 37.26779
# 11/11 - 1s - loss: 48.5064 - 1s/epoch - 133ms/step
# Epoch 51/1000
#
# Epoch 51: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.5573 - 2s/epoch - 140ms/step
# Epoch 52/1000
#
# Epoch 52: loss did not improve from 37.26779
# 11/11 - 1s - loss: 46.1378 - 1s/epoch - 129ms/step
# Epoch 53/1000
#
# Epoch 53: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.8736 - 2s/epoch - 138ms/step
# Epoch 54/1000
#
# Epoch 54: loss did not improve from 37.26779
# 11/11 - 2s - loss: 47.1650 - 2s/epoch - 138ms/step
# Epoch 55/1000
#
# Epoch 55: loss did not improve from 37.26779
# 11/11 - 1s - loss: 46.3080 - 1s/epoch - 132ms/step
# Epoch 56/1000
#
# Epoch 56: loss did not improve from 37.26779
# 11/11 - 1s - loss: 44.3559 - 1s/epoch - 126ms/step
# Epoch 57/1000
#
# Epoch 57: loss did not improve from 37.26779
# 11/11 - 1s - loss: 43.7417 - 1s/epoch - 133ms/step
# Epoch 58/1000
#
# Epoch 58: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.7200 - 2s/epoch - 140ms/step
# Epoch 59/1000
#
# Epoch 59: loss did not improve from 37.26779
# 11/11 - 1s - loss: 45.0343 - 1s/epoch - 132ms/step
# Epoch 60/1000
#
# Epoch 60: loss did not improve from 37.26779
# 11/11 - 1s - loss: 43.1536 - 1s/epoch - 132ms/step
# Epoch 61/1000
#
# Epoch 61: loss did not improve from 37.26779
# 11/11 - 2s - loss: 49.0128 - 2s/epoch - 140ms/step
# Epoch 62/1000
#
# Epoch 62: loss did not improve from 37.26779
# 11/11 - 1s - loss: 48.9660 - 1s/epoch - 132ms/step
# Epoch 63/1000
#
# Epoch 63: loss did not improve from 37.26779
# 11/11 - 1s - loss: 44.5914 - 1s/epoch - 127ms/step
# Epoch 64/1000
#
# Epoch 64: loss did not improve from 37.26779
# 11/11 - 1s - loss: 42.2298 - 1s/epoch - 133ms/step
# Epoch 65/1000
#
# Epoch 65: loss did not improve from 37.26779
# 11/11 - 2s - loss: 48.4952 - 2s/epoch - 139ms/step
# Epoch 66/1000
#
# Epoch 66: loss did not improve from 37.26779
# 11/11 - 1s - loss: 43.3769 - 1s/epoch - 131ms/step
# Epoch 67/1000
#
# Epoch 67: loss did not improve from 37.26779
# 11/11 - 1s - loss: 40.2151 - 1s/epoch - 133ms/step
# Epoch 68/1000
#
# Epoch 68: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.6883 - 2s/epoch - 140ms/step
# Epoch 69/1000
#
# Epoch 69: loss did not improve from 37.26779
# 11/11 - 1s - loss: 41.0614 - 1s/epoch - 129ms/step
# Epoch 70/1000
#
# Epoch 70: loss did not improve from 37.26779
# 11/11 - 1s - loss: 46.3981 - 1s/epoch - 131ms/step
# Epoch 71/1000
#
# Epoch 71: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.3878 - 2s/epoch - 137ms/step
# Epoch 72/1000
#
# Epoch 72: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.2556 - 2s/epoch - 147ms/step
# Epoch 73/1000
#
# Epoch 73: loss did not improve from 37.26779
# 11/11 - 1s - loss: 45.5427 - 1s/epoch - 130ms/step
# Epoch 74/1000
#
# Epoch 74: loss did not improve from 37.26779
# 11/11 - 1s - loss: 41.0359 - 1s/epoch - 133ms/step
# Epoch 75/1000
#
# Epoch 75: loss did not improve from 37.26779
# 11/11 - 2s - loss: 48.0985 - 2s/epoch - 140ms/step
# Epoch 76/1000
#
# Epoch 76: loss did not improve from 37.26779
# 11/11 - 1s - loss: 38.7924 - 1s/epoch - 136ms/step
# Epoch 77/1000
#
# Epoch 77: loss did not improve from 37.26779
# 11/11 - 2s - loss: 50.7408 - 2s/epoch - 138ms/step
# Epoch 78/1000
#
# Epoch 78: loss did not improve from 37.26779
# 11/11 - 2s - loss: 51.7434 - 2s/epoch - 167ms/step
# Epoch 79/1000
#
# Epoch 79: loss did not improve from 37.26779
# 11/11 - 2s - loss: 37.5074 - 2s/epoch - 150ms/step
# Epoch 80/1000
#
# Epoch 80: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.8971 - 2s/epoch - 168ms/step
# Epoch 81/1000
#
# Epoch 81: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.4856 - 2s/epoch - 184ms/step
# Epoch 82/1000
#
# Epoch 82: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.6740 - 2s/epoch - 161ms/step
# Epoch 83/1000
#
# Epoch 83: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.3549 - 2s/epoch - 161ms/step
# Epoch 84/1000
#
# Epoch 84: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.6913 - 2s/epoch - 174ms/step
# Epoch 85/1000
#
# Epoch 85: loss did not improve from 37.26779
# 11/11 - 1s - loss: 46.3940 - 1s/epoch - 129ms/step
# Epoch 86/1000
#
# Epoch 86: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.6017 - 2s/epoch - 149ms/step
# Epoch 87/1000
#
# Epoch 87: loss did not improve from 37.26779
# 11/11 - 2s - loss: 47.6335 - 2s/epoch - 146ms/step
# Epoch 88/1000
#
# Epoch 88: loss did not improve from 37.26779
# 11/11 - 1s - loss: 42.3680 - 1s/epoch - 132ms/step
# Epoch 89/1000
#
# Epoch 89: loss did not improve from 37.26779
# 11/11 - 2s - loss: 40.2384 - 2s/epoch - 147ms/step
# Epoch 90/1000
#
# Epoch 90: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.6683 - 2s/epoch - 151ms/step
# Epoch 91/1000
#
# Epoch 91: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.0000 - 2s/epoch - 142ms/step
# Epoch 92/1000
#
# Epoch 92: loss did not improve from 37.26779
# 11/11 - 1s - loss: 43.9564 - 1s/epoch - 136ms/step
# Epoch 93/1000
#
# Epoch 93: loss did not improve from 37.26779
# 11/11 - 2s - loss: 47.0866 - 2s/epoch - 150ms/step
# Epoch 94/1000
#
# Epoch 94: loss did not improve from 37.26779
# 11/11 - 4s - loss: 44.5026 - 4s/epoch - 353ms/step
# Epoch 95/1000
#
# Epoch 95: loss did not improve from 37.26779
# 11/11 - 2s - loss: 42.7122 - 2s/epoch - 158ms/step
# Epoch 96/1000
#
# Epoch 96: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.6213 - 2s/epoch - 169ms/step
# Epoch 97/1000
#
# Epoch 97: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.2241 - 2s/epoch - 138ms/step
# Epoch 98/1000
#
# Epoch 98: loss did not improve from 37.26779
# 11/11 - 2s - loss: 39.3515 - 2s/epoch - 157ms/step
# Epoch 99/1000
#
# Epoch 99: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.1746 - 2s/epoch - 156ms/step
# Epoch 100/1000
#
# Epoch 100: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.0792 - 2s/epoch - 149ms/step
# Epoch 101/1000
#
# Epoch 101: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.4744 - 2s/epoch - 155ms/step
# Epoch 102/1000
#
# Epoch 102: loss did not improve from 37.26779
# 11/11 - 1s - loss: 51.6016 - 1s/epoch - 134ms/step
# Epoch 103/1000
#
# Epoch 103: loss did not improve from 37.26779
# 11/11 - 2s - loss: 50.1947 - 2s/epoch - 141ms/step
# Epoch 104/1000
#
# Epoch 104: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.7558 - 2s/epoch - 164ms/step
# Epoch 105/1000
#
# Epoch 105: loss did not improve from 37.26779
# 11/11 - 2s - loss: 39.2565 - 2s/epoch - 137ms/step
# Epoch 106/1000
#
# Epoch 106: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.6933 - 2s/epoch - 145ms/step
# Epoch 107/1000
#
# Epoch 107: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.0899 - 2s/epoch - 147ms/step
# Epoch 108/1000
#
# Epoch 108: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.8043 - 2s/epoch - 136ms/step
# Epoch 109/1000
#
# Epoch 109: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.8435 - 2s/epoch - 141ms/step
# Epoch 110/1000
#
# Epoch 110: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.5709 - 2s/epoch - 161ms/step
# Epoch 111/1000
#
# Epoch 111: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.1720 - 2s/epoch - 170ms/step
# Epoch 112/1000
#
# Epoch 112: loss did not improve from 37.26779
# 11/11 - 1s - loss: 49.5061 - 1s/epoch - 135ms/step
# Epoch 113/1000
#
# Epoch 113: loss did not improve from 37.26779
# 11/11 - 1s - loss: 39.2106 - 1s/epoch - 134ms/step
# Epoch 114/1000
#
# Epoch 114: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.0741 - 2s/epoch - 146ms/step
# Epoch 115/1000
#
# Epoch 115: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.3414 - 2s/epoch - 140ms/step
# Epoch 116/1000
#
# Epoch 116: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.9910 - 2s/epoch - 142ms/step
# Epoch 117/1000
#
# Epoch 117: loss did not improve from 37.26779
# 11/11 - 2s - loss: 42.2864 - 2s/epoch - 160ms/step
# Epoch 118/1000
#
# Epoch 118: loss did not improve from 37.26779
# 11/11 - 1s - loss: 45.1914 - 1s/epoch - 133ms/step
# Epoch 119/1000
#
# Epoch 119: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.2856 - 2s/epoch - 144ms/step
# Epoch 120/1000
#
# Epoch 120: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.2236 - 2s/epoch - 150ms/step
# Epoch 121/1000
#
# Epoch 121: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.9538 - 2s/epoch - 159ms/step
# Epoch 122/1000
#
# Epoch 122: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.2407 - 2s/epoch - 150ms/step
# Epoch 123/1000
#
# Epoch 123: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.7528 - 2s/epoch - 168ms/step
# Epoch 124/1000
#
# Epoch 124: loss did not improve from 37.26779
# 11/11 - 1s - loss: 39.9338 - 1s/epoch - 135ms/step
# Epoch 125/1000
#
# Epoch 125: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.4081 - 2s/epoch - 160ms/step
# Epoch 126/1000
#
# Epoch 126: loss did not improve from 37.26779
# 11/11 - 2s - loss: 51.0901 - 2s/epoch - 152ms/step
# Epoch 127/1000
#
# Epoch 127: loss did not improve from 37.26779
# 11/11 - 2s - loss: 37.6726 - 2s/epoch - 141ms/step
# Epoch 128/1000
#
# Epoch 128: loss did not improve from 37.26779
# 11/11 - 2s - loss: 39.1856 - 2s/epoch - 146ms/step
# Epoch 129/1000
#
# Epoch 129: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.3661 - 2s/epoch - 151ms/step
# Epoch 130/1000
#
# Epoch 130: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.5934 - 2s/epoch - 150ms/step
# Epoch 131/1000
#
# Epoch 131: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.6972 - 2s/epoch - 144ms/step
# Epoch 132/1000
#
# Epoch 132: loss did not improve from 37.26779
# 11/11 - 2s - loss: 39.7244 - 2s/epoch - 153ms/step
# Epoch 133/1000
#
# Epoch 133: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.7910 - 2s/epoch - 151ms/step
# Epoch 134/1000
#
# Epoch 134: loss did not improve from 37.26779
# 11/11 - 2s - loss: 38.3985 - 2s/epoch - 138ms/step
# Epoch 135/1000
#
# Epoch 135: loss did not improve from 37.26779
# 11/11 - 2s - loss: 45.0698 - 2s/epoch - 147ms/step
# Epoch 136/1000
#
# Epoch 136: loss did not improve from 37.26779
# 11/11 - 2s - loss: 40.6384 - 2s/epoch - 146ms/step
# Epoch 137/1000
#
# Epoch 137: loss did not improve from 37.26779
# 11/11 - 2s - loss: 38.5842 - 2s/epoch - 137ms/step
# Epoch 138/1000
#
# Epoch 138: loss did not improve from 37.26779
# 11/11 - 2s - loss: 46.8367 - 2s/epoch - 148ms/step
# Epoch 139/1000
#
# Epoch 139: loss did not improve from 37.26779
# 11/11 - 2s - loss: 52.2627 - 2s/epoch - 147ms/step
# Epoch 140/1000
#
# Epoch 140: loss did not improve from 37.26779
# 11/11 - 2s - loss: 44.2247 - 2s/epoch - 141ms/step
# Epoch 141/1000
#
# Epoch 141: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.8108 - 2s/epoch - 152ms/step
# Epoch 142/1000
#
# Epoch 142: loss did not improve from 37.26779
# 11/11 - 2s - loss: 40.0034 - 2s/epoch - 157ms/step
# Epoch 143/1000
#
# Epoch 143: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.6794 - 2s/epoch - 150ms/step
# Epoch 144/1000
#
# Epoch 144: loss did not improve from 37.26779
# 11/11 - 2s - loss: 42.2388 - 2s/epoch - 146ms/step
# Epoch 145/1000
#
# Epoch 145: loss did not improve from 37.26779
# 11/11 - 2s - loss: 41.0191 - 2s/epoch - 151ms/step
# Epoch 146/1000
#
# Epoch 146: loss did not improve from 37.26779
# 11/11 - 2s - loss: 48.2433 - 2s/epoch - 149ms/step
# Epoch 147/1000
#
# Epoch 147: loss did not improve from 37.26779
# 11/11 - 2s - loss: 43.2165 - 2s/epoch - 171ms/step
# Epoch 148/1000
#
# Epoch 148: loss did not improve from 37.26779
# 11/11 - 2s - loss: 50.8571 - 2s/epoch - 189ms/step
# Epoch 149/1000
#
# Epoch 149: loss improved from 37.26779 to 31.82659, saving model to model_GRU.h5
# 11/11 - 2s - loss: 31.8266 - 2s/epoch - 181ms/step
# Epoch 150/1000
#
# Epoch 150: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.3962 - 2s/epoch - 156ms/step
# Epoch 151/1000
#
# Epoch 151: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.0409 - 2s/epoch - 139ms/step
# Epoch 152/1000
#
# Epoch 152: loss did not improve from 31.82659
# 11/11 - 1s - loss: 46.1996 - 1s/epoch - 134ms/step
# Epoch 153/1000
#
# Epoch 153: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.2493 - 2s/epoch - 147ms/step
# Epoch 154/1000
#
# Epoch 154: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.8267 - 2s/epoch - 150ms/step
# Epoch 155/1000
#
# Epoch 155: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.3626 - 2s/epoch - 139ms/step
# Epoch 156/1000
#
# Epoch 156: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.3708 - 2s/epoch - 140ms/step
# Epoch 157/1000
#
# Epoch 157: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.5153 - 2s/epoch - 151ms/step
# Epoch 158/1000
#
# Epoch 158: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.3769 - 2s/epoch - 145ms/step
# Epoch 159/1000
#
# Epoch 159: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.4553 - 2s/epoch - 152ms/step
# Epoch 160/1000
#
# Epoch 160: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.4335 - 2s/epoch - 169ms/step
# Epoch 161/1000
#
# Epoch 161: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.3267 - 2s/epoch - 157ms/step
# Epoch 162/1000
#
# Epoch 162: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.4313 - 2s/epoch - 145ms/step
# Epoch 163/1000
#
# Epoch 163: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.5106 - 2s/epoch - 163ms/step
# Epoch 164/1000
#
# Epoch 164: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.0394 - 2s/epoch - 163ms/step
# Epoch 165/1000
#
# Epoch 165: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.3476 - 2s/epoch - 176ms/step
# Epoch 166/1000
#
# Epoch 166: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.5845 - 2s/epoch - 147ms/step
# Epoch 167/1000
#
# Epoch 167: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.2595 - 2s/epoch - 143ms/step
# Epoch 168/1000
#
# Epoch 168: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.5860 - 2s/epoch - 141ms/step
# Epoch 169/1000
#
# Epoch 169: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.1409 - 2s/epoch - 147ms/step
# Epoch 170/1000
#
# Epoch 170: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.4098 - 2s/epoch - 137ms/step
# Epoch 171/1000
#
# Epoch 171: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.6393 - 2s/epoch - 140ms/step
# Epoch 172/1000
#
# Epoch 172: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6975 - 2s/epoch - 139ms/step
# Epoch 173/1000
#
# Epoch 173: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.7447 - 2s/epoch - 140ms/step
# Epoch 174/1000
#
# Epoch 174: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.4383 - 2s/epoch - 137ms/step
# Epoch 175/1000
#
# Epoch 175: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.6629 - 2s/epoch - 145ms/step
# Epoch 176/1000
#
# Epoch 176: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.8177 - 2s/epoch - 147ms/step
# Epoch 177/1000
#
# Epoch 177: loss did not improve from 31.82659
# 11/11 - 1s - loss: 41.3065 - 1s/epoch - 135ms/step
# Epoch 178/1000
#
# Epoch 178: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.7490 - 2s/epoch - 146ms/step
# Epoch 179/1000
#
# Epoch 179: loss did not improve from 31.82659
# 11/11 - 2s - loss: 51.3503 - 2s/epoch - 148ms/step
# Epoch 180/1000
#
# Epoch 180: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.0417 - 2s/epoch - 139ms/step
# Epoch 181/1000
#
# Epoch 181: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.0504 - 2s/epoch - 138ms/step
# Epoch 182/1000
#
# Epoch 182: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.6898 - 2s/epoch - 153ms/step
# Epoch 183/1000
#
# Epoch 183: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.8219 - 2s/epoch - 137ms/step
# Epoch 184/1000
#
# Epoch 184: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.1661 - 2s/epoch - 150ms/step
# Epoch 185/1000
#
# Epoch 185: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.4329 - 2s/epoch - 158ms/step
# Epoch 186/1000
#
# Epoch 186: loss did not improve from 31.82659
# 11/11 - 2s - loss: 36.7229 - 2s/epoch - 139ms/step
# Epoch 187/1000
#
# Epoch 187: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.4893 - 2s/epoch - 147ms/step
# Epoch 188/1000
#
# Epoch 188: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.4545 - 2s/epoch - 163ms/step
# Epoch 189/1000
#
# Epoch 189: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.0925 - 2s/epoch - 154ms/step
# Epoch 190/1000
#
# Epoch 190: loss did not improve from 31.82659
# 11/11 - 4s - loss: 45.1057 - 4s/epoch - 407ms/step
# Epoch 191/1000
#
# Epoch 191: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.9166 - 2s/epoch - 190ms/step
# Epoch 192/1000
#
# Epoch 192: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.7950 - 2s/epoch - 206ms/step
# Epoch 193/1000
#
# Epoch 193: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.5031 - 2s/epoch - 162ms/step
# Epoch 194/1000
#
# Epoch 194: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.3735 - 2s/epoch - 145ms/step
# Epoch 195/1000
#
# Epoch 195: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.3585 - 2s/epoch - 173ms/step
# Epoch 196/1000
#
# Epoch 196: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.9084 - 2s/epoch - 185ms/step
# Epoch 197/1000
#
# Epoch 197: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.1990 - 2s/epoch - 187ms/step
# Epoch 198/1000
#
# Epoch 198: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.6163 - 2s/epoch - 158ms/step
# Epoch 199/1000
#
# Epoch 199: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.5263 - 2s/epoch - 153ms/step
# Epoch 200/1000
#
# Epoch 200: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.9960 - 2s/epoch - 158ms/step
# Epoch 201/1000
#
# Epoch 201: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.2387 - 2s/epoch - 141ms/step
# Epoch 202/1000
#
# Epoch 202: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.6515 - 2s/epoch - 140ms/step
# Epoch 203/1000
#
# Epoch 203: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.5971 - 2s/epoch - 151ms/step
# Epoch 204/1000
#
# Epoch 204: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.1300 - 2s/epoch - 151ms/step
# Epoch 205/1000
#
# Epoch 205: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.4731 - 2s/epoch - 149ms/step
# Epoch 206/1000
#
# Epoch 206: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.7574 - 2s/epoch - 148ms/step
# Epoch 207/1000
#
# Epoch 207: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.1354 - 2s/epoch - 150ms/step
# Epoch 208/1000
#
# Epoch 208: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.3612 - 2s/epoch - 142ms/step
# Epoch 209/1000
#
# Epoch 209: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.0633 - 2s/epoch - 155ms/step
# Epoch 210/1000
#
# Epoch 210: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.6269 - 2s/epoch - 155ms/step
# Epoch 211/1000
#
# Epoch 211: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.4460 - 2s/epoch - 141ms/step
# Epoch 212/1000
#
# Epoch 212: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.8973 - 2s/epoch - 184ms/step
# Epoch 213/1000
#
# Epoch 213: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.4134 - 2s/epoch - 189ms/step
# Epoch 214/1000
#
# Epoch 214: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.6659 - 2s/epoch - 143ms/step
# Epoch 215/1000
#
# Epoch 215: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.3069 - 2s/epoch - 209ms/step
# Epoch 216/1000
#
# Epoch 216: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.7358 - 2s/epoch - 152ms/step
# Epoch 217/1000
#
# Epoch 217: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.8994 - 2s/epoch - 163ms/step
# Epoch 218/1000
#
# Epoch 218: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.9131 - 2s/epoch - 183ms/step
# Epoch 219/1000
#
# Epoch 219: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.6243 - 2s/epoch - 158ms/step
# Epoch 220/1000
#
# Epoch 220: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.2710 - 2s/epoch - 154ms/step
# Epoch 221/1000
#
# Epoch 221: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.2944 - 2s/epoch - 155ms/step
# Epoch 222/1000
#
# Epoch 222: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.0158 - 2s/epoch - 142ms/step
# Epoch 223/1000
#
# Epoch 223: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.5200 - 2s/epoch - 146ms/step
# Epoch 224/1000
#
# Epoch 224: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.5461 - 2s/epoch - 156ms/step
# Epoch 225/1000
#
# Epoch 225: loss did not improve from 31.82659
# 11/11 - 2s - loss: 51.2595 - 2s/epoch - 151ms/step
# Epoch 226/1000
#
# Epoch 226: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.3206 - 2s/epoch - 141ms/step
# Epoch 227/1000
#
# Epoch 227: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.0373 - 2s/epoch - 153ms/step
# Epoch 228/1000
#
# Epoch 228: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.0400 - 2s/epoch - 147ms/step
# Epoch 229/1000
#
# Epoch 229: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.2543 - 2s/epoch - 149ms/step
# Epoch 230/1000
#
# Epoch 230: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.4840 - 2s/epoch - 156ms/step
# Epoch 231/1000
#
# Epoch 231: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.9573 - 2s/epoch - 144ms/step
# Epoch 232/1000
#
# Epoch 232: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.4109 - 2s/epoch - 140ms/step
# Epoch 233/1000
#
# Epoch 233: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.3064 - 2s/epoch - 167ms/step
# Epoch 234/1000
#
# Epoch 234: loss did not improve from 31.82659
# 11/11 - 2s - loss: 51.2944 - 2s/epoch - 145ms/step
# Epoch 235/1000
#
# Epoch 235: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.0963 - 2s/epoch - 138ms/step
# Epoch 236/1000
#
# Epoch 236: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.6843 - 2s/epoch - 151ms/step
# Epoch 237/1000
#
# Epoch 237: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.4327 - 2s/epoch - 147ms/step
# Epoch 238/1000
#
# Epoch 238: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6339 - 2s/epoch - 139ms/step
# Epoch 239/1000
#
# Epoch 239: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.5434 - 2s/epoch - 151ms/step
# Epoch 240/1000
#
# Epoch 240: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.0702 - 2s/epoch - 152ms/step
# Epoch 241/1000
#
# Epoch 241: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.6814 - 2s/epoch - 148ms/step
# Epoch 242/1000
#
# Epoch 242: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.8428 - 2s/epoch - 147ms/step
# Epoch 243/1000
#
# Epoch 243: loss did not improve from 31.82659
# 11/11 - 2s - loss: 35.3838 - 2s/epoch - 154ms/step
# Epoch 244/1000
#
# Epoch 244: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.9316 - 2s/epoch - 147ms/step
# Epoch 245/1000
#
# Epoch 245: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.5259 - 2s/epoch - 147ms/step
# Epoch 246/1000
#
# Epoch 246: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.2678 - 2s/epoch - 152ms/step
# Epoch 247/1000
#
# Epoch 247: loss did not improve from 31.82659
# 11/11 - 1s - loss: 46.7245 - 1s/epoch - 136ms/step
# Epoch 248/1000
#
# Epoch 248: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.7085 - 2s/epoch - 146ms/step
# Epoch 249/1000
#
# Epoch 249: loss did not improve from 31.82659
# 11/11 - 2s - loss: 35.7540 - 2s/epoch - 160ms/step
# Epoch 250/1000
#
# Epoch 250: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.7846 - 2s/epoch - 139ms/step
# Epoch 251/1000
#
# Epoch 251: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.4621 - 2s/epoch - 144ms/step
# Epoch 252/1000
#
# Epoch 252: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.2939 - 2s/epoch - 148ms/step
# Epoch 253/1000
#
# Epoch 253: loss did not improve from 31.82659
# 11/11 - 2s - loss: 51.5932 - 2s/epoch - 136ms/step
# Epoch 254/1000
#
# Epoch 254: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.3848 - 2s/epoch - 139ms/step
# Epoch 255/1000
#
# Epoch 255: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.0869 - 2s/epoch - 146ms/step
# Epoch 256/1000
#
# Epoch 256: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.6803 - 2s/epoch - 142ms/step
# Epoch 257/1000
#
# Epoch 257: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.2264 - 2s/epoch - 139ms/step
# Epoch 258/1000
#
# Epoch 258: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.2485 - 2s/epoch - 147ms/step
# Epoch 259/1000
#
# Epoch 259: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.2486 - 2s/epoch - 158ms/step
# Epoch 260/1000
#
# Epoch 260: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.4839 - 2s/epoch - 137ms/step
# Epoch 261/1000
#
# Epoch 261: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.1691 - 2s/epoch - 140ms/step
# Epoch 262/1000
#
# Epoch 262: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.5887 - 2s/epoch - 179ms/step
# Epoch 263/1000
#
# Epoch 263: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.8786 - 2s/epoch - 157ms/step
# Epoch 264/1000
#
# Epoch 264: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.4728 - 2s/epoch - 155ms/step
# Epoch 265/1000
#
# Epoch 265: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.5049 - 2s/epoch - 152ms/step
# Epoch 266/1000
#
# Epoch 266: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.3289 - 2s/epoch - 178ms/step
# Epoch 267/1000
#
# Epoch 267: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.8561 - 2s/epoch - 146ms/step
# Epoch 268/1000
#
# Epoch 268: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.8043 - 2s/epoch - 142ms/step
# Epoch 269/1000
#
# Epoch 269: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.0824 - 2s/epoch - 145ms/step
# Epoch 270/1000
#
# Epoch 270: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.1685 - 2s/epoch - 174ms/step
# Epoch 271/1000
#
# Epoch 271: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.8748 - 2s/epoch - 156ms/step
# Epoch 272/1000
#
# Epoch 272: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.5648 - 2s/epoch - 143ms/step
# Epoch 273/1000
#
# Epoch 273: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.2571 - 2s/epoch - 164ms/step
# Epoch 274/1000
#
# Epoch 274: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.6296 - 2s/epoch - 172ms/step
# Epoch 275/1000
#
# Epoch 275: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.8947 - 2s/epoch - 142ms/step
# Epoch 276/1000
#
# Epoch 276: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.7255 - 2s/epoch - 159ms/step
# Epoch 277/1000
#
# Epoch 277: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.0612 - 2s/epoch - 154ms/step
# Epoch 278/1000
#
# Epoch 278: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.1976 - 2s/epoch - 150ms/step
# Epoch 279/1000
#
# Epoch 279: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.8043 - 2s/epoch - 156ms/step
# Epoch 280/1000
#
# Epoch 280: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.8380 - 2s/epoch - 154ms/step
# Epoch 281/1000
#
# Epoch 281: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.8893 - 2s/epoch - 153ms/step
# Epoch 282/1000
#
# Epoch 282: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.0014 - 2s/epoch - 153ms/step
# Epoch 283/1000
#
# Epoch 283: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.8509 - 2s/epoch - 147ms/step
# Epoch 284/1000
#
# Epoch 284: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.7710 - 2s/epoch - 143ms/step
# Epoch 285/1000
#
# Epoch 285: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.9239 - 2s/epoch - 148ms/step
# Epoch 286/1000
#
# Epoch 286: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.2815 - 2s/epoch - 146ms/step
# Epoch 287/1000
#
# Epoch 287: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.6976 - 2s/epoch - 146ms/step
# Epoch 288/1000
#
# Epoch 288: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.7919 - 2s/epoch - 144ms/step
# Epoch 289/1000
#
# Epoch 289: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.9032 - 2s/epoch - 158ms/step
# Epoch 290/1000
#
# Epoch 290: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.3472 - 2s/epoch - 138ms/step
# Epoch 291/1000
#
# Epoch 291: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.4633 - 2s/epoch - 160ms/step
# Epoch 292/1000
#
# Epoch 292: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.0166 - 2s/epoch - 155ms/step
# Epoch 293/1000
#
# Epoch 293: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.0758 - 2s/epoch - 141ms/step
# Epoch 294/1000
#
# Epoch 294: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.3382 - 2s/epoch - 144ms/step
# Epoch 295/1000
#
# Epoch 295: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.0006 - 2s/epoch - 153ms/step
# Epoch 296/1000
#
# Epoch 296: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.9235 - 2s/epoch - 148ms/step
# Epoch 297/1000
#
# Epoch 297: loss did not improve from 31.82659
# 11/11 - 2s - loss: 51.6447 - 2s/epoch - 150ms/step
# Epoch 298/1000
#
# Epoch 298: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.1496 - 2s/epoch - 160ms/step
# Epoch 299/1000
#
# Epoch 299: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.5958 - 2s/epoch - 160ms/step
# Epoch 300/1000
#
# Epoch 300: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.0053 - 2s/epoch - 145ms/step
# Epoch 301/1000
#
# Epoch 301: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.8329 - 2s/epoch - 155ms/step
# Epoch 302/1000
#
# Epoch 302: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.9375 - 2s/epoch - 144ms/step
# Epoch 303/1000
#
# Epoch 303: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.5773 - 2s/epoch - 153ms/step
# Epoch 304/1000
#
# Epoch 304: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.2793 - 2s/epoch - 157ms/step
# Epoch 305/1000
#
# Epoch 305: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.2361 - 2s/epoch - 142ms/step
# Epoch 306/1000
#
# Epoch 306: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.1911 - 2s/epoch - 154ms/step
# Epoch 307/1000
#
# Epoch 307: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.7327 - 2s/epoch - 161ms/step
# Epoch 308/1000
#
# Epoch 308: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.5868 - 2s/epoch - 138ms/step
# Epoch 309/1000
#
# Epoch 309: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.4066 - 2s/epoch - 148ms/step
# Epoch 310/1000
#
# Epoch 310: loss did not improve from 31.82659
# 11/11 - 2s - loss: 56.5872 - 2s/epoch - 155ms/step
# Epoch 311/1000
#
# Epoch 311: loss did not improve from 31.82659
# 11/11 - 2s - loss: 50.5617 - 2s/epoch - 148ms/step
# Epoch 312/1000
#
# Epoch 312: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.7774 - 2s/epoch - 144ms/step
# Epoch 313/1000
#
# Epoch 313: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.1871 - 2s/epoch - 155ms/step
# Epoch 314/1000
#
# Epoch 314: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.9390 - 2s/epoch - 155ms/step
# Epoch 315/1000
#
# Epoch 315: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.1947 - 2s/epoch - 143ms/step
# Epoch 316/1000
#
# Epoch 316: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.6847 - 2s/epoch - 151ms/step
# Epoch 317/1000
#
# Epoch 317: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.6564 - 2s/epoch - 146ms/step
# Epoch 318/1000
#
# Epoch 318: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.3391 - 2s/epoch - 142ms/step
# Epoch 319/1000
#
# Epoch 319: loss did not improve from 31.82659
# 11/11 - 2s - loss: 36.4723 - 2s/epoch - 153ms/step
# Epoch 320/1000
#
# Epoch 320: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.6704 - 2s/epoch - 146ms/step
# Epoch 321/1000
#
# Epoch 321: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7592 - 2s/epoch - 137ms/step
# Epoch 322/1000
#
# Epoch 322: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.0130 - 2s/epoch - 152ms/step
# Epoch 323/1000
#
# Epoch 323: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.0947 - 2s/epoch - 149ms/step
# Epoch 324/1000
#
# Epoch 324: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.2606 - 2s/epoch - 136ms/step
# Epoch 325/1000
#
# Epoch 325: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.5567 - 2s/epoch - 142ms/step
# Epoch 326/1000
#
# Epoch 326: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.4991 - 2s/epoch - 149ms/step
# Epoch 327/1000
#
# Epoch 327: loss did not improve from 31.82659
# 11/11 - 1s - loss: 40.5795 - 1s/epoch - 135ms/step
# Epoch 328/1000
#
# Epoch 328: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.1542 - 2s/epoch - 140ms/step
# Epoch 329/1000
#
# Epoch 329: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6284 - 2s/epoch - 148ms/step
# Epoch 330/1000
#
# Epoch 330: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.0418 - 2s/epoch - 140ms/step
# Epoch 331/1000
#
# Epoch 331: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.7108 - 2s/epoch - 140ms/step
# Epoch 332/1000
#
# Epoch 332: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.7736 - 2s/epoch - 146ms/step
# Epoch 333/1000
#
# Epoch 333: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.8333 - 2s/epoch - 142ms/step
# Epoch 334/1000
#
# Epoch 334: loss did not improve from 31.82659
# 11/11 - 1s - loss: 39.4564 - 1s/epoch - 133ms/step
# Epoch 335/1000
#
# Epoch 335: loss did not improve from 31.82659
# 11/11 - 2s - loss: 35.4465 - 2s/epoch - 142ms/step
# Epoch 336/1000
#
# Epoch 336: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.2382 - 2s/epoch - 145ms/step
# Epoch 337/1000
#
# Epoch 337: loss did not improve from 31.82659
# 11/11 - 1s - loss: 42.4826 - 1s/epoch - 134ms/step
# Epoch 338/1000
#
# Epoch 338: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.2485 - 2s/epoch - 145ms/step
# Epoch 339/1000
#
# Epoch 339: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.9166 - 2s/epoch - 146ms/step
# Epoch 340/1000
#
# Epoch 340: loss did not improve from 31.82659
# 11/11 - 1s - loss: 48.1969 - 1s/epoch - 132ms/step
# Epoch 341/1000
#
# Epoch 341: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.6491 - 2s/epoch - 138ms/step
# Epoch 342/1000
#
# Epoch 342: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.8150 - 2s/epoch - 145ms/step
# Epoch 343/1000
#
# Epoch 343: loss did not improve from 31.82659
# 11/11 - 1s - loss: 47.9687 - 1s/epoch - 136ms/step
# Epoch 344/1000
#
# Epoch 344: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.6834 - 2s/epoch - 140ms/step
# Epoch 345/1000
#
# Epoch 345: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.7561 - 2s/epoch - 146ms/step
# Epoch 346/1000
#
# Epoch 346: loss did not improve from 31.82659
# 11/11 - 2s - loss: 37.2342 - 2s/epoch - 140ms/step
# Epoch 347/1000
#
# Epoch 347: loss did not improve from 31.82659
# 11/11 - 1s - loss: 42.6324 - 1s/epoch - 132ms/step
# Epoch 348/1000
#
# Epoch 348: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.7136 - 2s/epoch - 140ms/step
# Epoch 349/1000
#
# Epoch 349: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.7966 - 2s/epoch - 149ms/step
# Epoch 350/1000
#
# Epoch 350: loss did not improve from 31.82659
# 11/11 - 1s - loss: 41.0348 - 1s/epoch - 133ms/step
# Epoch 351/1000
#
# Epoch 351: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.0767 - 2s/epoch - 142ms/step
# Epoch 352/1000
#
# Epoch 352: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.0835 - 2s/epoch - 156ms/step
# Epoch 353/1000
#
# Epoch 353: loss did not improve from 31.82659
# 11/11 - 1s - loss: 39.5073 - 1s/epoch - 136ms/step
# Epoch 354/1000
#
# Epoch 354: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.3085 - 2s/epoch - 150ms/step
# Epoch 355/1000
#
# Epoch 355: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.2256 - 2s/epoch - 156ms/step
# Epoch 356/1000
#
# Epoch 356: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.2441 - 2s/epoch - 144ms/step
# Epoch 357/1000
#
# Epoch 357: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.4822 - 2s/epoch - 140ms/step
# Epoch 358/1000
#
# Epoch 358: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.3073 - 2s/epoch - 148ms/step
# Epoch 359/1000
#
# Epoch 359: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.3049 - 2s/epoch - 158ms/step
# Epoch 360/1000
#
# Epoch 360: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.3938 - 2s/epoch - 139ms/step
# Epoch 361/1000
#
# Epoch 361: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.1134 - 2s/epoch - 148ms/step
# Epoch 362/1000
#
# Epoch 362: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.8241 - 2s/epoch - 150ms/step
# Epoch 363/1000
#
# Epoch 363: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.1285 - 2s/epoch - 142ms/step
# Epoch 364/1000
#
# Epoch 364: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.5073 - 2s/epoch - 141ms/step
# Epoch 365/1000
#
# Epoch 365: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.5932 - 2s/epoch - 146ms/step
# Epoch 366/1000
#
# Epoch 366: loss did not improve from 31.82659
# 11/11 - 1s - loss: 38.5975 - 1s/epoch - 134ms/step
# Epoch 367/1000
#
# Epoch 367: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.8722 - 2s/epoch - 142ms/step
# Epoch 368/1000
#
# Epoch 368: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.8710 - 2s/epoch - 153ms/step
# Epoch 369/1000
#
# Epoch 369: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.8923 - 2s/epoch - 142ms/step
# Epoch 370/1000
#
# Epoch 370: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7499 - 2s/epoch - 147ms/step
# Epoch 371/1000
#
# Epoch 371: loss did not improve from 31.82659
# 11/11 - 2s - loss: 38.5318 - 2s/epoch - 150ms/step
# Epoch 372/1000
#
# Epoch 372: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.2477 - 2s/epoch - 155ms/step
# Epoch 373/1000
#
# Epoch 373: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.9005 - 2s/epoch - 141ms/step
# Epoch 374/1000
#
# Epoch 374: loss did not improve from 31.82659
# 11/11 - 2s - loss: 35.1699 - 2s/epoch - 167ms/step
# Epoch 375/1000
#
# Epoch 375: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7498 - 2s/epoch - 153ms/step
# Epoch 376/1000
#
# Epoch 376: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.8302 - 2s/epoch - 154ms/step
# Epoch 377/1000
#
# Epoch 377: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.8030 - 2s/epoch - 191ms/step
# Epoch 378/1000
#
# Epoch 378: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.5498 - 2s/epoch - 163ms/step
# Epoch 379/1000
#
# Epoch 379: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.5618 - 2s/epoch - 159ms/step
# Epoch 380/1000
#
# Epoch 380: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.8222 - 2s/epoch - 159ms/step
# Epoch 381/1000
#
# Epoch 381: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.2614 - 2s/epoch - 149ms/step
# Epoch 382/1000
#
# Epoch 382: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.8536 - 2s/epoch - 156ms/step
# Epoch 383/1000
#
# Epoch 383: loss did not improve from 31.82659
# 11/11 - 2s - loss: 49.5695 - 2s/epoch - 155ms/step
# Epoch 384/1000
#
# Epoch 384: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.7837 - 2s/epoch - 181ms/step
# Epoch 385/1000
#
# Epoch 385: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.3557 - 2s/epoch - 205ms/step
# Epoch 386/1000
#
# Epoch 386: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.1061 - 2s/epoch - 156ms/step
# Epoch 387/1000
#
# Epoch 387: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.4141 - 2s/epoch - 148ms/step
# Epoch 388/1000
#
# Epoch 388: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.4455 - 2s/epoch - 161ms/step
# Epoch 389/1000
#
# Epoch 389: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6780 - 2s/epoch - 161ms/step
# Epoch 390/1000
#
# Epoch 390: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.4117 - 2s/epoch - 163ms/step
# Epoch 391/1000
#
# Epoch 391: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.1239 - 2s/epoch - 170ms/step
# Epoch 392/1000
#
# Epoch 392: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7005 - 2s/epoch - 146ms/step
# Epoch 393/1000
#
# Epoch 393: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.8819 - 2s/epoch - 155ms/step
# Epoch 394/1000
#
# Epoch 394: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.3196 - 2s/epoch - 159ms/step
# Epoch 395/1000
#
# Epoch 395: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.0928 - 2s/epoch - 204ms/step
# Epoch 396/1000
#
# Epoch 396: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.9367 - 2s/epoch - 155ms/step
# Epoch 397/1000
#
# Epoch 397: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.4477 - 2s/epoch - 169ms/step
# Epoch 398/1000
#
# Epoch 398: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.7830 - 2s/epoch - 150ms/step
# Epoch 399/1000
#
# Epoch 399: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.4906 - 2s/epoch - 154ms/step
# Epoch 400/1000
#
# Epoch 400: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.4738 - 2s/epoch - 148ms/step
# Epoch 401/1000
#
# Epoch 401: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.2363 - 2s/epoch - 142ms/step
# Epoch 402/1000
#
# Epoch 402: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.2980 - 2s/epoch - 165ms/step
# Epoch 403/1000
#
# Epoch 403: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.1838 - 2s/epoch - 149ms/step
# Epoch 404/1000
#
# Epoch 404: loss did not improve from 31.82659
# 11/11 - 2s - loss: 47.2508 - 2s/epoch - 139ms/step
# Epoch 405/1000
#
# Epoch 405: loss did not improve from 31.82659
# 11/11 - 2s - loss: 40.7019 - 2s/epoch - 148ms/step
# Epoch 406/1000
#
# Epoch 406: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.7460 - 2s/epoch - 155ms/step
# Epoch 407/1000
#
# Epoch 407: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.3141 - 2s/epoch - 139ms/step
# Epoch 408/1000
#
# Epoch 408: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.5324 - 2s/epoch - 167ms/step
# Epoch 409/1000
#
# Epoch 409: loss did not improve from 31.82659
# 11/11 - 2s - loss: 41.5204 - 2s/epoch - 167ms/step
# Epoch 410/1000
#
# Epoch 410: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6774 - 2s/epoch - 139ms/step
# Epoch 411/1000
#
# Epoch 411: loss did not improve from 31.82659
# 11/11 - 2s - loss: 35.6601 - 2s/epoch - 160ms/step
# Epoch 412/1000
#
# Epoch 412: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.5321 - 2s/epoch - 163ms/step
# Epoch 413/1000
#
# Epoch 413: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7870 - 2s/epoch - 139ms/step
# Epoch 414/1000
#
# Epoch 414: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.4231 - 2s/epoch - 148ms/step
# Epoch 415/1000
#
# Epoch 415: loss did not improve from 31.82659
# 11/11 - 2s - loss: 46.1772 - 2s/epoch - 163ms/step
# Epoch 416/1000
#
# Epoch 416: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.6775 - 2s/epoch - 142ms/step
# Epoch 417/1000
#
# Epoch 417: loss did not improve from 31.82659
# 11/11 - 2s - loss: 42.7195 - 2s/epoch - 150ms/step
# Epoch 418/1000
#
# Epoch 418: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.5127 - 2s/epoch - 157ms/step
# Epoch 419/1000
#
# Epoch 419: loss did not improve from 31.82659
# 11/11 - 2s - loss: 48.7211 - 2s/epoch - 160ms/step
# Epoch 420/1000
#
# Epoch 420: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.1295 - 2s/epoch - 150ms/step
# Epoch 421/1000
#
# Epoch 421: loss did not improve from 31.82659
# 11/11 - 2s - loss: 45.2240 - 2s/epoch - 159ms/step
# Epoch 422/1000
#
# Epoch 422: loss did not improve from 31.82659
# 11/11 - 2s - loss: 39.0859 - 2s/epoch - 143ms/step
# Epoch 423/1000
#
# Epoch 423: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.5714 - 2s/epoch - 157ms/step
# Epoch 424/1000
#
# Epoch 424: loss did not improve from 31.82659
# 11/11 - 2s - loss: 44.3703 - 2s/epoch - 155ms/step
# Epoch 425/1000
#
# Epoch 425: loss did not improve from 31.82659
# 11/11 - 2s - loss: 43.6657 - 2s/epoch - 141ms/step
# Epoch 426/1000
#
# ...
# 11/11 - 2s - loss: 44.5989 - 2s/epoch - 140ms/step
# Epoch 860/1000
#
# Epoch 860: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.3833 - 2s/epoch - 141ms/step
# Epoch 861/1000
#
# Epoch 861: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.6567 - 2s/epoch - 147ms/step
# Epoch 862/1000
#
# Epoch 862: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.4480 - 2s/epoch - 158ms/step
# Epoch 863/1000
#
# Epoch 863: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.8888 - 2s/epoch - 146ms/step
# Epoch 864/1000
#
# Epoch 864: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.9531 - 2s/epoch - 153ms/step
# Epoch 865/1000
#
# Epoch 865: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.3166 - 2s/epoch - 147ms/step
# Epoch 866/1000
#
# Epoch 866: loss did not improve from 31.72785
# 11/11 - 1s - loss: 38.7349 - 1s/epoch - 136ms/step
# Epoch 867/1000
#
# Epoch 867: loss did not improve from 31.72785
# 11/11 - 2s - loss: 34.2653 - 2s/epoch - 146ms/step
# Epoch 868/1000
#
# Epoch 868: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.5492 - 2s/epoch - 153ms/step
# Epoch 869/1000
#
# Epoch 869: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.4159 - 2s/epoch - 145ms/step
# Epoch 870/1000
#
# Epoch 870: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.3844 - 2s/epoch - 148ms/step
# Epoch 871/1000
#
# Epoch 871: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.8632 - 2s/epoch - 152ms/step
# Epoch 872/1000
#
# Epoch 872: loss did not improve from 31.72785
# 11/11 - 2s - loss: 32.7871 - 2s/epoch - 142ms/step
# Epoch 873/1000
#
# Epoch 873: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.9010 - 2s/epoch - 158ms/step
# Epoch 874/1000
#
# Epoch 874: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.1867 - 2s/epoch - 154ms/step
# Epoch 875/1000
#
# Epoch 875: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.1510 - 2s/epoch - 138ms/step
# Epoch 876/1000
#
# Epoch 876: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.3930 - 2s/epoch - 150ms/step
# Epoch 877/1000
#
# Epoch 877: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.4820 - 2s/epoch - 151ms/step
# Epoch 878/1000
#
# Epoch 878: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.9964 - 2s/epoch - 138ms/step
# Epoch 879/1000
#
# Epoch 879: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.1050 - 2s/epoch - 140ms/step
# Epoch 880/1000
#
# Epoch 880: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.4660 - 2s/epoch - 150ms/step
# Epoch 881/1000
#
# Epoch 881: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.9939 - 2s/epoch - 152ms/step
# Epoch 882/1000
#
# Epoch 882: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.3563 - 2s/epoch - 140ms/step
# Epoch 883/1000
#
# Epoch 883: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.6052 - 2s/epoch - 152ms/step
# Epoch 884/1000
#
# Epoch 884: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.1857 - 2s/epoch - 149ms/step
# Epoch 885/1000
#
# Epoch 885: loss did not improve from 31.72785
# 11/11 - 2s - loss: 44.3050 - 2s/epoch - 144ms/step
# Epoch 886/1000
#
# Epoch 886: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.1622 - 2s/epoch - 146ms/step
# Epoch 887/1000
#
# Epoch 887: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.8881 - 2s/epoch - 158ms/step
# Epoch 888/1000
#
# Epoch 888: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.2635 - 2s/epoch - 141ms/step
# Epoch 889/1000
#
# Epoch 889: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.1174 - 2s/epoch - 159ms/step
# Epoch 890/1000
#
# Epoch 890: loss did not improve from 31.72785
# 11/11 - 2s - loss: 45.2896 - 2s/epoch - 155ms/step
# Epoch 891/1000
#
# Epoch 891: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.3657 - 2s/epoch - 141ms/step
# Epoch 892/1000
#
# Epoch 892: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.8915 - 2s/epoch - 147ms/step
# Epoch 893/1000
#
# Epoch 893: loss did not improve from 31.72785
# 11/11 - 2s - loss: 44.8613 - 2s/epoch - 160ms/step
# Epoch 894/1000
#
# Epoch 894: loss did not improve from 31.72785
# 11/11 - 2s - loss: 44.2014 - 2s/epoch - 141ms/step
# Epoch 895/1000
#
# Epoch 895: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.9932 - 2s/epoch - 149ms/step
# Epoch 896/1000
#
# Epoch 896: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.5496 - 2s/epoch - 154ms/step
# Epoch 897/1000
#
# Epoch 897: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.9369 - 2s/epoch - 146ms/step
# Epoch 898/1000
#
# Epoch 898: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.6379 - 2s/epoch - 147ms/step
# Epoch 899/1000
#
# Epoch 899: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.0544 - 2s/epoch - 153ms/step
# Epoch 900/1000
#
# Epoch 900: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.0847 - 2s/epoch - 146ms/step
# Epoch 901/1000
#
# Epoch 901: loss did not improve from 31.72785
# 11/11 - 2s - loss: 45.5096 - 2s/epoch - 155ms/step
# Epoch 902/1000
#
# Epoch 902: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.3744 - 2s/epoch - 155ms/step
# Epoch 903/1000
#
# Epoch 903: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.8415 - 2s/epoch - 141ms/step
# Epoch 904/1000
#
# Epoch 904: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.1529 - 2s/epoch - 149ms/step
# Epoch 905/1000
#
# Epoch 905: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.5702 - 2s/epoch - 160ms/step
# Epoch 906/1000
#
# Epoch 906: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.2006 - 2s/epoch - 138ms/step
# Epoch 907/1000
#
# Epoch 907: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.9607 - 2s/epoch - 143ms/step
# Epoch 908/1000
#
# Epoch 908: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.3665 - 2s/epoch - 154ms/step
# Epoch 909/1000
#
# Epoch 909: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.2875 - 2s/epoch - 149ms/step
# Epoch 910/1000
#
# Epoch 910: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.5786 - 2s/epoch - 138ms/step
# Epoch 911/1000
#
# Epoch 911: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.0514 - 2s/epoch - 148ms/step
# Epoch 912/1000
#
# Epoch 912: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.2142 - 2s/epoch - 144ms/step
# Epoch 913/1000
#
# Epoch 913: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.5975 - 2s/epoch - 141ms/step
# Epoch 914/1000
#
# Epoch 914: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.5969 - 2s/epoch - 146ms/step
# Epoch 915/1000
#
# Epoch 915: loss did not improve from 31.72785
# 11/11 - 2s - loss: 45.7338 - 2s/epoch - 150ms/step
# Epoch 916/1000
#
# Epoch 916: loss did not improve from 31.72785
# 11/11 - 1s - loss: 37.5885 - 1s/epoch - 135ms/step
# Epoch 917/1000
#
# Epoch 917: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.0603 - 2s/epoch - 149ms/step
# Epoch 918/1000
#
# Epoch 918: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.0634 - 2s/epoch - 151ms/step
# Epoch 919/1000
#
# Epoch 919: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.4516 - 2s/epoch - 138ms/step
# Epoch 920/1000
#
# Epoch 920: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.1980 - 2s/epoch - 142ms/step
# Epoch 921/1000
#
# Epoch 921: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.9759 - 2s/epoch - 153ms/step
# Epoch 922/1000
#
# Epoch 922: loss did not improve from 31.72785
# 11/11 - 1s - loss: 39.2693 - 1s/epoch - 134ms/step
# Epoch 923/1000
#
# Epoch 923: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.2554 - 2s/epoch - 140ms/step
# Epoch 924/1000
#
# Epoch 924: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.2099 - 2s/epoch - 147ms/step
# Epoch 925/1000
#
# Epoch 925: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.5167 - 2s/epoch - 143ms/step
# Epoch 926/1000
#
# Epoch 926: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.5984 - 2s/epoch - 136ms/step
# Epoch 927/1000
#
# Epoch 927: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.5369 - 2s/epoch - 148ms/step
# Epoch 928/1000
#
# Epoch 928: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.6206 - 2s/epoch - 143ms/step
# Epoch 929/1000
#
# Epoch 929: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.2911 - 2s/epoch - 143ms/step
# Epoch 930/1000
#
# Epoch 930: loss did not improve from 31.72785
# 11/11 - 2s - loss: 45.1384 - 2s/epoch - 141ms/step
# Epoch 931/1000
#
# Epoch 931: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.7613 - 2s/epoch - 148ms/step
# Epoch 932/1000
#
# Epoch 932: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.6100 - 2s/epoch - 136ms/step
# Epoch 933/1000
#
# Epoch 933: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.4736 - 2s/epoch - 149ms/step
# Epoch 934/1000
#
# Epoch 934: loss did not improve from 31.72785
# 11/11 - 2s - loss: 32.5538 - 2s/epoch - 148ms/step
# Epoch 935/1000
#
# Epoch 935: loss did not improve from 31.72785
# 11/11 - 1s - loss: 45.6177 - 1s/epoch - 135ms/step
# Epoch 936/1000
#
# Epoch 936: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.0646 - 2s/epoch - 141ms/step
# Epoch 937/1000
#
# Epoch 937: loss did not improve from 31.72785
# 11/11 - 2s - loss: 45.4666 - 2s/epoch - 154ms/step
# Epoch 938/1000
#
# Epoch 938: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.8282 - 2s/epoch - 136ms/step
# Epoch 939/1000
#
# Epoch 939: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.9908 - 2s/epoch - 139ms/step
# Epoch 940/1000
#
# Epoch 940: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.0585 - 2s/epoch - 147ms/step
# Epoch 941/1000
#
# Epoch 941: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.7017 - 2s/epoch - 141ms/step
# Epoch 942/1000
#
# Epoch 942: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.9270 - 2s/epoch - 143ms/step
# Epoch 943/1000
#
# Epoch 943: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.5547 - 2s/epoch - 145ms/step
# Epoch 944/1000
#
# Epoch 944: loss did not improve from 31.72785
# 11/11 - 2s - loss: 44.2281 - 2s/epoch - 146ms/step
# Epoch 945/1000
#
# Epoch 945: loss did not improve from 31.72785
# 11/11 - 1s - loss: 43.0346 - 1s/epoch - 135ms/step
# Epoch 946/1000
#
# Epoch 946: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.3805 - 2s/epoch - 145ms/step
# Epoch 947/1000
#
# Epoch 947: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.0438 - 2s/epoch - 146ms/step
# Epoch 948/1000
#
# Epoch 948: loss did not improve from 31.72785
# 11/11 - 1s - loss: 34.1361 - 1s/epoch - 134ms/step
# Epoch 949/1000
#
# Epoch 949: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.0046 - 2s/epoch - 148ms/step
# Epoch 950/1000
#
# Epoch 950: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.0417 - 2s/epoch - 149ms/step
# Epoch 951/1000
#
# Epoch 951: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.6178 - 2s/epoch - 137ms/step
# Epoch 952/1000
#
# Epoch 952: loss did not improve from 31.72785
# 11/11 - 1s - loss: 36.7944 - 1s/epoch - 135ms/step
# Epoch 953/1000
#
# Epoch 953: loss did not improve from 31.72785
# 11/11 - 2s - loss: 32.5969 - 2s/epoch - 143ms/step
# Epoch 954/1000
#
# Epoch 954: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.2289 - 2s/epoch - 141ms/step
# Epoch 955/1000
#
# Epoch 955: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.2127 - 2s/epoch - 138ms/step
# Epoch 956/1000
#
# Epoch 956: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.9314 - 2s/epoch - 138ms/step
# Epoch 957/1000
#
# Epoch 957: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.0858 - 2s/epoch - 150ms/step
# Epoch 958/1000
#
# Epoch 958: loss did not improve from 31.72785
# 11/11 - 1s - loss: 38.3453 - 1s/epoch - 133ms/step
# Epoch 959/1000
#
# Epoch 959: loss did not improve from 31.72785
# 11/11 - 1s - loss: 41.2774 - 1s/epoch - 135ms/step
# Epoch 960/1000
#
# Epoch 960: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.0452 - 2s/epoch - 153ms/step
# Epoch 961/1000
#
# Epoch 961: loss did not improve from 31.72785
# 11/11 - 1s - loss: 38.7874 - 1s/epoch - 135ms/step
# Epoch 962/1000
#
# Epoch 962: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.3763 - 2s/epoch - 137ms/step
# Epoch 963/1000
#
# Epoch 963: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.0734 - 2s/epoch - 145ms/step
# Epoch 964/1000
#
# Epoch 964: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.4633 - 2s/epoch - 146ms/step
# Epoch 965/1000
#
# Epoch 965: loss did not improve from 31.72785
# 11/11 - 1s - loss: 38.7967 - 1s/epoch - 134ms/step
# Epoch 966/1000
#
# Epoch 966: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.6369 - 2s/epoch - 138ms/step
# Epoch 967/1000
#
# Epoch 967: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.2254 - 2s/epoch - 146ms/step
# Epoch 968/1000
#
# Epoch 968: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.6092 - 2s/epoch - 139ms/step
# Epoch 969/1000
#
# Epoch 969: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.6010 - 2s/epoch - 138ms/step
# Epoch 970/1000
#
# Epoch 970: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.0787 - 2s/epoch - 147ms/step
# Epoch 971/1000
#
# Epoch 971: loss did not improve from 31.72785
# 11/11 - 1s - loss: 40.4241 - 1s/epoch - 133ms/step
# Epoch 972/1000
#
# Epoch 972: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.0463 - 2s/epoch - 145ms/step
# Epoch 973/1000
#
# Epoch 973: loss did not improve from 31.72785
# 11/11 - 2s - loss: 42.5334 - 2s/epoch - 149ms/step
# Epoch 974/1000
#
# Epoch 974: loss did not improve from 31.72785
# 11/11 - 1s - loss: 38.3335 - 1s/epoch - 136ms/step
# Epoch 975/1000
#
# Epoch 975: loss did not improve from 31.72785
# 11/11 - 1s - loss: 40.3465 - 1s/epoch - 135ms/step
# Epoch 976/1000
#
# Epoch 976: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.5607 - 2s/epoch - 153ms/step
# Epoch 977/1000
#
# Epoch 977: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.9853 - 2s/epoch - 141ms/step
# Epoch 978/1000
#
# Epoch 978: loss did not improve from 31.72785
# 11/11 - 1s - loss: 40.7352 - 1s/epoch - 134ms/step
# Epoch 979/1000
#
# Epoch 979: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.2669 - 2s/epoch - 139ms/step
# Epoch 980/1000
#
# Epoch 980: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.8885 - 2s/epoch - 155ms/step
# Epoch 981/1000
#
# Epoch 981: loss did not improve from 31.72785
# 11/11 - 1s - loss: 41.6520 - 1s/epoch - 135ms/step
# Epoch 982/1000
#
# Epoch 982: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.1003 - 2s/epoch - 137ms/step
# Epoch 983/1000
#
# Epoch 983: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.0067 - 2s/epoch - 146ms/step
# Epoch 984/1000
#
# Epoch 984: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.1520 - 2s/epoch - 141ms/step
# Epoch 985/1000
#
# Epoch 985: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.8757 - 2s/epoch - 137ms/step
# Epoch 986/1000
#
# Epoch 986: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.5198 - 2s/epoch - 145ms/step
# Epoch 987/1000
#
# Epoch 987: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.0828 - 2s/epoch - 138ms/step
# Epoch 988/1000
#
# Epoch 988: loss did not improve from 31.72785
# 11/11 - 2s - loss: 40.0580 - 2s/epoch - 138ms/step
# Epoch 989/1000
#
# Epoch 989: loss did not improve from 31.72785
# 11/11 - 2s - loss: 37.7372 - 2s/epoch - 140ms/step
# Epoch 990/1000
#
# Epoch 990: loss did not improve from 31.72785
# 11/11 - 2s - loss: 43.2166 - 2s/epoch - 143ms/step
# Epoch 991/1000
#
# Epoch 991: loss did not improve from 31.72785
# 11/11 - 1s - loss: 44.5334 - 1s/epoch - 132ms/step
# Epoch 992/1000
#
# Epoch 992: loss did not improve from 31.72785
# 11/11 - 2s - loss: 36.9274 - 2s/epoch - 138ms/step
# Epoch 993/1000
#
# Epoch 993: loss did not improve from 31.72785
# 11/11 - 2s - loss: 35.0336 - 2s/epoch - 150ms/step
# Epoch 994/1000
#
# Epoch 994: loss did not improve from 31.72785
# 11/11 - 1s - loss: 41.3212 - 1s/epoch - 132ms/step
# Epoch 995/1000
#
# Epoch 995: loss did not improve from 31.72785
# 11/11 - 2s - loss: 44.9198 - 2s/epoch - 138ms/step
# Epoch 996/1000
#
# Epoch 996: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.7651 - 2s/epoch - 143ms/step
# Epoch 997/1000
#
# Epoch 997: loss did not improve from 31.72785
# 11/11 - 2s - loss: 38.1068 - 2s/epoch - 143ms/step
# Epoch 998/1000
#
# Epoch 998: loss did not improve from 31.72785
# 11/11 - 1s - loss: 40.6794 - 1s/epoch - 133ms/step
# Epoch 999/1000
#
# Epoch 999: loss did not improve from 31.72785
# 11/11 - 2s - loss: 41.7315 - 2s/epoch - 145ms/step
# Epoch 1000/1000
#
# Epoch 1000: loss did not improve from 31.72785
# 11/11 - 2s - loss: 39.4151 - 2s/epoch - 143ms/step

# %%
loss = history.history['loss']
epochs = range(len(loss))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Task 2: Evaluating the performance of trained model on the testset

# %% [markdown]
# ### 2.1. Predict the price of stock
# Prepare the datatest in structure of timesteps = 60

# %%
# Construct datatest with 60 timesteps
test_data = df_TSM["Close"][400-60:].values
X_test = []
for i in range(60,len(test_data)):
    X_test.append(test_data[i-60:i])
X_test = np.array(X_test)
X_test= np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
print(X_test.shape)
# Out:
# (103, 60, 1)

# %%
# predict the price of stock
pred_test = model_GRU.predict(X_test)
# Out:
# 4/4 [==============================] - 2s 40ms/step

# %%
y_test = df_TSM["Close"][400:]

# %% [markdown]
# ### 2.2. Compute the metrics (quantitative measurements)

# %%
# R2-score:
score = r2_score(y_pred=pred_test,y_true=y_test)
print("The R2 score of our model is: ",score)
# Out:
# The R2 score of our model is:  0.8179618336566687

# %%
# Mean Absolute Error:
mae_score = mean_absolute_error(y_pred=pred_test,y_true=y_test)
print("The mean absolute error of our model is: ", mae_score)
# Out:
# The mean absolute error of our model is:  1.7570788189045434

# %%
#  Root Mean Squared Error (RMSE):
rmse_score = np.sqrt(mean_squared_error(y_pred=pred_test,y_true=y_test))
print("The root mean squared error of our model is:", rmse_score)
# Out:
# The root mean squared error of our model is: 2.161229286506061

# %%
# Visulize result Close price
fig, ax = plt.subplots(1,1,figsize = (16,8))

ax.plot(df_TSM.index[:], df_TSM['Close'], color='blue', label = 'Train Stock Price')
ax.plot(y_test.index, y_test, color = 'green', label = 'Real Stock Price')
ax.plot(y_test.index, pred_test[:,0].tolist(), color = 'red', label = 'Predicted Stock Price')
fig.suptitle('TSMC Stock Close Price Prediction')
ax.set_xlabel('Time')
ax.set_ylabel('Close Price')
ax.set_xticks(df_TSM.index.tolist()[::30]) #Without this it is too dense, with this we only display every after 30 xticks
ax.set_xticklabels(ax.get_xticklabels(),rotation = 40, ha = 'center')# Shearing the labels to 40 degree and write it in center

ax.legend()
ax.grid(True)

plt.show()
